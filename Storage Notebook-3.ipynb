# %% [markdown]
# # This Notebook represents the corelation of the other elements that effect on <mark>"Solenoid Valve"</mark> from the given <mark>"Cold Storage Dataset"</mark>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cold = pd.read_excel("D:\Hitesh Files\Room_1_2_3_4_MF001_Processed_Data.xlsx")
cold
# Out:
#           P_ID  MF_ID              P_Date    Room  Solenoid  Room_Temp  \
# 0      4601771  MF001 2023-04-01 11:16:16  Room-1         1       17.8
# 1      4601798  MF001 2023-04-01 11:21:23  Room-1         1       18.0
# 2      4601821  MF001 2023-04-01 11:26:36  Room-1         1       18.0
# 3      4602187  MF001 2023-04-01 12:49:20  Room-1         1       14.0
# 4      4602214  MF001 2023-04-01 12:54:31  Room-1         1       13.7
# ...        ...    ...                 ...     ...       ...        ...
# 24130  4822330  MF001 2023-07-03 18:05:21  Room-4         0       27.2
# 24131  4822345  MF001 2023-07-03 18:10:29  Room-4         0       27.1
# 24132  4822362  MF001 2023-07-03 18:15:40  Room-4         0       27.1
# 24133  4822379  MF001 2023-07-03 18:20:49  Room-4         0       27.1
# 24134  4822395  MF001 2023-07-03 18:25:59  Room-4         0       27.1
#
#        Temp_1  Temp_2  Temp_3  Temp_4  ...  Zone_1_Color  Zone_2_Color  \
# ...

# %%
cold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24135 entries, 0 to 24134
# Data columns (total 49 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   P_ID               24135 non-null  int64
#  1   MF_ID              24135 non-null  object
#  2   P_Date             24135 non-null  datetime64[ns]
#  3   Room               24135 non-null  object
#  4   Solenoid           24135 non-null  int64
#  5   Room_Temp          24135 non-null  float64
#  6   Temp_1             24135 non-null  float64
#  7   Temp_2             24135 non-null  float64
#  8   Temp_3             24135 non-null  float64
#  9   Temp_4             24135 non-null  float64
#  10  Temp_5             24135 non-null  float64
#  11  Temp_6             24135 non-null  float64
#  12  Temp_7             24135 non-null  float64
#  13  Temp_8             24135 non-null  float64
#  14  Temp_9             24135 non-null  float64
# ...

# %%
cold.columns
# Out:
# Index(['P_ID', 'MF_ID', 'P_Date', 'Room', 'Solenoid', 'Room_Temp', 'Temp_1',
#        'Temp_2', 'Temp_3', 'Temp_4', 'Temp_5', 'Temp_6', 'Temp_7', 'Temp_8',
#        'Temp_9', 'Temp_10', 'Temp_11', 'Temp_12', 'Temp_Avg', 'Room_Hum',
#        'Humidity_1', 'Humidity_2', 'Humidity_Avg', 'Heater_1',
#        'Heater_1_current', 'Heater_2', 'Heater_2_current', 'Heater_Avg',
#        'Fan_1', 'Fan_1_CFM_Percent', 'Fan_2', 'Fan_2_CFM_Percent', 'Fan_3',
#        'Fan_3_CFM_Percent', 'Fan_4', 'Fan_4_CFM_Percent', 'Fan_CFM_Avg',
#        'Temp_Color', 'Hum_Color', 'Zone_1_Color', 'Zone_2_Color',
#        'Zone_3_Color', 'Zone_4_Color', 'MF1_Temp_SP', 'MF1_Temp_Diff',
#        'MF1_Temp_Range', 'MF1_Hum_SP', 'MF1_Hum_Diff', 'MF1_Hum_Range'],
#       dtype='object')

# %% [markdown]
# # **<mark>Finding Correlation and Plotting it</mark>**

# %%
# Calculate correlation 

correlation = cold[['Solenoid', 'Room_Temp', 'Room_Hum']].corr()

print("Correlation Matrix:")
print(correlation)

# Bifurcate data room-wise
rooms = cold['Room'].unique()

for room in rooms:
    room_data = cold[cold['Room'] == room]
    room_correlation = room_data[['Solenoid', 'Room_Temp', 'Room_Hum']].corr()
    print(f"\nCorrelation Matrix for Room {room}:")
room_correlation
# Out:
# Correlation Matrix:
#            Solenoid  Room_Temp  Room_Hum
# Solenoid   1.000000  -0.056603  0.177312
# Room_Temp -0.056603   1.000000 -0.567116
# Room_Hum   0.177312  -0.567116  1.000000
#
# Correlation Matrix for Room Room-1:
#
# Correlation Matrix for Room Room-2:
#
# Correlation Matrix for Room Room-3:
#
# Correlation Matrix for Room Room-4:
#            Solenoid  Room_Temp  Room_Hum
# Solenoid   1.000000  -0.040022  0.152478
# Room_Temp -0.040022   1.000000 -0.693021
# Room_Hum   0.152478  -0.693021  1.000000

# %%
# Full correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation, annot=True, cmap='RdBu', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
# Calculate correlation 

correlation = cold[['Solenoid', 'Fan_1', 'Fan_2', 'Fan_3', 'Fan_4']].corr()

print("Correlation Matrix:")
print(correlation)
# Out:
# Correlation Matrix:
#           Solenoid     Fan_1     Fan_2     Fan_3     Fan_4
# Solenoid  1.000000  0.597065  0.597289  0.597513  0.598183
# Fan_1     0.597065  1.000000  0.999625  0.999251  0.998131
# Fan_2     0.597289  0.999625  1.000000  0.999626  0.998505
# Fan_3     0.597513  0.999251  0.999626  1.000000  0.998879
# Fan_4     0.598183  0.998131  0.998505  0.998879  1.000000

# %%
# Full correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True,cmap='RdBu', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
# Calculate correlation 

correlation = cold[['Heater_1', 'Fan_1', 'Fan_2', 'Fan_3', 'Fan_4']].corr()
print("Correlation Matrix:")
correlation 

# Full correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap='RdBu', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()
# Out:
# Correlation Matrix:

# %%
# Calculate correlation 

correlation = cold[['Solenoid', 'Room_Temp', 'Room_Hum', 'Heater_1', 'Fan_1', 'Fan_2', 'Fan_3', 'Fan_4', 'Fan_CFM_Avg', 'MF1_Temp_SP', 'MF1_Hum_SP', 'Heater_1']].corr()

print("Correlation Matrix:")
correlation
# Out:
# Correlation Matrix:
#              Solenoid  Room_Temp  Room_Hum  Heater_1     Fan_1     Fan_2  \
# Solenoid     1.000000  -0.056603  0.177312  0.194896  0.597065  0.597289
# Room_Temp   -0.056603   1.000000 -0.567116  0.252426 -0.046753 -0.046718
# Room_Hum     0.177312  -0.567116  1.000000  0.140873  0.072093  0.071814
# Heater_1     0.194896   0.252426  0.140873  1.000000  0.116366  0.116409
# Fan_1        0.597065  -0.046753  0.072093  0.116366  1.000000  0.999625
# Fan_2        0.597289  -0.046718  0.071814  0.116409  0.999625  1.000000
# Fan_3        0.597513  -0.046797  0.071843  0.116453  0.999251  0.999626
# Fan_4        0.598183  -0.046179  0.071586  0.116584  0.998131  0.998505
# Fan_CFM_Avg  0.250124   0.330873 -0.272256  0.308068  0.648778  0.648726
# MF1_Temp_SP -0.184921   0.579250 -0.354392  0.390409  0.064707  0.064893
# MF1_Hum_SP   0.188154  -0.592462  0.400607 -0.396153 -0.033174 -0.033110
# Heater_1     0.194896   0.252426  0.140873  1.000000  0.116366  0.116409
# ...

# %%
# Full correlation matrix
plt.figure(figsize=(15, 10))
sns.heatmap(correlation, annot=True, cmap='RdBu', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # **<mark>Date and Time calculation of Solenoid Switches</mark>**

# %%
colds = cold[['P_ID', 'P_Date', 'Room', 'Solenoid', 'Room_Temp', 'Temp_Avg', 'Room_Hum', 'Heater_1', 'Humidity_Avg', 'Fan_1', 'Fan_2', 'Fan_3', 'Fan_4']]
colds
# Out:
#           P_ID              P_Date    Room  Solenoid  Room_Temp  Temp_Avg  \
# 0      4601771 2023-04-01 11:16:16  Room-1         1       17.8      17.7
# 1      4601798 2023-04-01 11:21:23  Room-1         1       18.0      17.7
# 2      4601821 2023-04-01 11:26:36  Room-1         1       18.0       0.0
# 3      4602187 2023-04-01 12:49:20  Room-1         1       14.0      14.2
# 4      4602214 2023-04-01 12:54:31  Room-1         1       13.7      13.6
# ...        ...                 ...     ...       ...        ...       ...
# 24130  4822330 2023-07-03 18:05:21  Room-4         0       27.2       0.0
# 24131  4822345 2023-07-03 18:10:29  Room-4         0       27.1       0.0
# 24132  4822362 2023-07-03 18:15:40  Room-4         0       27.1       0.0
# 24133  4822379 2023-07-03 18:20:49  Room-4         0       27.1       0.0
# 24134  4822395 2023-07-03 18:25:59  Room-4         0       27.1       0.0
#
#        Room_Hum  Heater_1  Humidity_Avg  Fan_1  Fan_2  Fan_3  Fan_4
# ...

# %%
colds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24135 entries, 0 to 24134
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   P_ID          24135 non-null  int64
#  1   P_Date        24135 non-null  datetime64[ns]
#  2   Room          24135 non-null  object
#  3   Solenoid      24135 non-null  int64
#  4   Room_Temp     24135 non-null  float64
#  5   Temp_Avg      24135 non-null  float64
#  6   Room_Hum      24135 non-null  float64
#  7   Heater_1      24135 non-null  int64
#  8   Humidity_Avg  24135 non-null  float64
#  9   Fan_1         24135 non-null  int64
#  10  Fan_2         24135 non-null  int64
#  11  Fan_3         24135 non-null  int64
#  12  Fan_4         24135 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(7), object(1)
# memory usage: 2.4+ MB

# %% [markdown]
# # **<mark>ROOM 1</mark>**

# %%
cold1 = cold[['P_ID', 'P_Date', 'Room', 'Solenoid', 'Room_Temp', 'Temp_Avg', 'Room_Hum', 'Humidity_Avg', 'Heater_1', 'Fan_1', 'Fan_2', 'Fan_3', 'Fan_4']]
cold1 = cold1[cold1["Room"]=="Room-1"].reset_index(drop=True)
cold1
# Out:
#          P_ID              P_Date    Room  Solenoid  Room_Temp  Temp_Avg  \
# 0     4601771 2023-04-01 11:16:16  Room-1         1       17.8      17.7
# 1     4601798 2023-04-01 11:21:23  Room-1         1       18.0      17.7
# 2     4601821 2023-04-01 11:26:36  Room-1         1       18.0       0.0
# 3     4602187 2023-04-01 12:49:20  Room-1         1       14.0      14.2
# 4     4602214 2023-04-01 12:54:31  Room-1         1       13.7      13.6
# ...       ...                 ...     ...       ...        ...       ...
# 6654  4822333 2023-07-03 18:06:39  Room-1         1       27.2       0.0
# 6655  4822366 2023-07-03 18:16:52  Room-1         1       27.2       0.0
# 6656  4822382 2023-07-03 18:22:04  Room-1         1       27.2       0.0
# 6657  4822399 2023-07-03 18:27:15  Room-1         1       27.2       0.0
# 6658  4829967 2023-07-12 15:45:43  Room-1         1       26.0      26.1
#
#       Room_Hum  Humidity_Avg  Heater_1  Fan_1  Fan_2  Fan_3  Fan_4
# ...

# %% [markdown]
# ## **_1) Solenoid Valve_**

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Iterate through each row in the dataset
for index, row in cold1.iterrows():
    date = row['P_Date'].date()
    solenoid = row['Solenoid']
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold1.loc[index - 1, 'Solenoid']
        if solenoid != prev_solenoid:
            if solenoid == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1

# Print count of solenoid ON and OFF for each date
for date, count in solenoid_on_count.items():
    off_count = solenoid_off_count.get(date, 0)
    print(f"{date}:  ON:   {count},            OFF:  {off_count},          Total Switches: {count + off_count}")


# Convert dictionaries to lists for plotting
dates = list(solenoid_on_count.keys())
on_counts = list(solenoid_on_count.values())
off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
plt.figure(figsize=(15, 5))
plt.bar(dates, on_counts, color='green', label='Solenoid ON')
plt.bar(dates, off_counts, color='yellow', bottom=on_counts, label='Solenoid OFF')
plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Solenoid ON/OFF Count for Each Date')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 2023-04-01:  ON:   1,            OFF:  1,          Total Switches: 2
# 2023-04-02:  ON:   2,            OFF:  2,          Total Switches: 4
# 2023-04-03:  ON:   2,            OFF:  2,          Total Switches: 4
# 2023-04-04:  ON:   3,            OFF:  3,          Total Switches: 6
# 2023-04-05:  ON:   2,            OFF:  3,          Total Switches: 5
# 2023-04-11:  ON:   1,            OFF:  0,          Total Switches: 1
# 2023-04-25:  ON:   1,            OFF:  0,          Total Switches: 1
# 2023-04-26:  ON:   1,            OFF:  1,          Total Switches: 2
# 2023-04-27:  ON:   3,            OFF:  3,          Total Switches: 6
# 2023-05-04:  ON:   1,            OFF:  1,          Total Switches: 2
# 2023-05-05:  ON:   1,            OFF:  1,          Total Switches: 2
# 2023-05-07:  ON:   1,            OFF:  1,          Total Switches: 2
# 2023-05-09:  ON:   1,            OFF:  1,          Total Switches: 2
# 2023-05-10:  ON:   1,            OFF:  1,          Total Switches: 2
# ...

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Initialize lists to store room temperature data
room_temp_dates = []
room_temp_values = []

# Iterate through each row in the dataset
for index, row in cold1.iterrows():
    date = row['P_Date'].date()
    solenoid = row['Solenoid']
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold1.loc[index - 1, 'Solenoid']
        if solenoid != prev_solenoid:
            if solenoid == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1
    
    # Store room temperature data
    room_temp_dates.append(date)
    room_temp_values.append(row['Room_Temp'])

# Convert dictionaries to lists for plotting
dates = list(solenoid_on_count.keys())
on_counts = list(solenoid_on_count.values())
off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
fig, ax1 = plt.subplots(figsize=(15, 5))
ax2 = ax1.twinx()

# Plot solenoid ON/OFF counts
ax1.bar(dates, on_counts, color='green', label='Solenoid ON')
ax1.bar(dates, off_counts, color='yellow', bottom=on_counts, label='Solenoid OFF')
ax1.set_xlabel('Date')
ax1.set_ylabel('Count')
ax1.set_title('Solenoid ON/OFF Count and Room Temperature')
ax1.legend(loc='upper left')
ax1.tick_params(axis='x', rotation=45)

# Plot room temperature
ax2.plot(room_temp_dates, room_temp_values, color='red', linestyle='-', label='Room Temp')
ax2.set_ylabel('Room Temperature')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Initialize lists to store room humidity data
room_hum_dates = []
room_hum_values = []

# Iterate through each row in the dataset
for index, row in cold1.iterrows():
    date = row['P_Date'].date()
    solenoid = row['Solenoid']
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold1.loc[index - 1, 'Solenoid']
        if solenoid != prev_solenoid:
            if solenoid == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1
    
    # Store room humidity data
    room_hum_dates.append(date)
    room_hum_values.append(row['Room_Hum'])

# Convert dictionaries to lists for plotting
dates = list(solenoid_on_count.keys())
on_counts = list(solenoid_on_count.values())
off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
fig, ax1 = plt.subplots(figsize=(15, 6))
ax2 = ax1.twinx()

# Plot solenoid ON/OFF counts
ax1.bar(dates, on_counts, color='green', label='Solenoid ON')
ax1.bar(dates, off_counts, color='yellow', bottom=on_counts, label='Solenoid OFF')
ax1.set_xlabel('Date')
ax1.set_ylabel('Count')
ax1.set_title('Solenoid ON/OFF Count and Room Humidity')
ax1.legend(loc='upper left')
ax1.tick_params(axis='x', rotation=45)

# Plot room humidity
ax2.plot(room_hum_dates, room_hum_values, color='blue', linestyle='-', label='Room Hum')
ax2.set_ylabel('Room Humidity')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Initialize lists to store room temperature and humidity data
room_temp_dates = []
room_temp_values = []
room_hum_values = []

# Iterate through each row in the dataset
for index, row in cold1.iterrows():
    date = row['P_Date'].date()
    solenoid = row['Solenoid']
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold1.loc[index - 1, 'Solenoid']
        if solenoid != prev_solenoid:
            if solenoid == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1
    
    # Store room temperature and humidity data
    room_temp_dates.append(date)
    room_temp_values.append(row['Room_Temp'])
    room_hum_values.append(row['Room_Hum'])

# Convert dictionaries to lists for plotting
dates = list(solenoid_on_count.keys())
on_counts = list(solenoid_on_count.values())
off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 8))
ax2 = ax1.twinx()

# Plot solenoid ON/OFF counts
ax1.bar(dates, on_counts, color='green', label='Solenoid ON')
ax1.bar(dates, off_counts, color='yellow', bottom=on_counts, label='Solenoid OFF')
ax1.set_xlabel('Date')
ax1.set_ylabel('Count')
ax1.set_title('Solenoid ON/OFF Count, Room Temperature, and Room Humidity')
ax1.legend(loc='upper left')
ax1.tick_params(axis='x', rotation=45)

# Plot room temperature
ax2.plot(room_temp_dates, room_temp_values, color='red', linestyle='-', label='Room Temp')
ax2.plot(room_temp_dates, room_hum_values, color='blue', linestyle='-', label='Room Humidity')
ax2.set_ylabel('Temperature/Humidity')
ax2.set_ylim(0, 100)
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
from datetime import datetime, timedelta

# Initialize dictionaries to track time for each state
solenoid_on_time = {}
solenoid_off_time = {}

# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Iterate through each row in the dataset
for index, row in cold1.iterrows():
    date = row['P_Date'].date()
    solenoid = row['Solenoid']
    timestamp = row['P_Date']
    
    # Initialize time if not present
    if date not in solenoid_on_time:
        solenoid_on_time[date] = timedelta()
    if date not in solenoid_off_time:
        solenoid_off_time[date] = timedelta()
    
    # Initialize count if not present
    if date not in solenoid_on_count:
        solenoid_on_count[date] = 0
    if date not in solenoid_off_count:
        solenoid_off_count[date] = 0
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold1.loc[index - 1, 'Solenoid']
        prev_timestamp = cold1.loc[index - 1, 'P_Date']
        
        if solenoid != prev_solenoid:
            time_diff = timestamp - prev_timestamp
            if solenoid == 1:
                solenoid_on_time[date] += time_diff
                solenoid_on_count[date] += 1
            else:
                solenoid_off_time[date] += time_diff
                solenoid_off_count[date] += 1

# Print count of solenoid ON and OFF for each date
for date, count in solenoid_on_count.items():
    off_count = solenoid_off_count.get(date, 0)
    print(f"{date}:    ON: {count},  {solenoid_on_time[date]},                  OFF: {off_count},  {solenoid_off_time[date]}")
    print (f"               Total Count: {count + off_count}                Total timing: {solenoid_on_time[date] + solenoid_off_time[date]}")


# Print total time ON and OFF for each date
for date, time_on in solenoid_on_time.items():
    time_off = solenoid_off_time[date]
    total_time_on = time_on.total_seconds()
    total_time_off = time_off.total_seconds()
    total_time = total_time_on + total_time_off


# Convert timedelta to seconds for plotting
time_on_seconds = {date: time.total_seconds() for date, time in solenoid_on_time.items()}
time_off_seconds = {date: time.total_seconds() for date, time in solenoid_off_time.items()}

# Plotting
plt.figure(figsize=(10, 6))

plt.plot(list(time_on_seconds.keys()), list(time_on_seconds.values()), label='Time ON', marker='o', color='Green')
plt.plot(list(time_off_seconds.keys()), list(time_off_seconds.values()), label='Time OFF', marker='o', color='yellow')

plt.title('Solenoid ON/OFF Time')
plt.xlabel('Date')
plt.ylabel('Time (seconds)')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()
# Out:
# 2023-04-01:    ON: 1,  0 days 00:05:11,                  OFF: 1,  0 days 00:05:11
#                Total Count: 2                Total timing: 0 days 00:10:22
# 2023-04-02:    ON: 2,  0 days 00:10:20,                  OFF: 2,  0 days 00:10:18
#                Total Count: 4                Total timing: 0 days 00:20:38
# 2023-04-03:    ON: 2,  0 days 00:10:20,                  OFF: 2,  0 days 00:10:20
#                Total Count: 4                Total timing: 0 days 00:20:40
# 2023-04-04:    ON: 3,  0 days 00:15:32,                  OFF: 3,  0 days 00:15:50
#                Total Count: 6                Total timing: 0 days 00:31:22
# 2023-04-05:    ON: 2,  0 days 01:22:55,                  OFF: 3,  0 days 00:15:32
#                Total Count: 5                Total timing: 0 days 01:38:27
# 2023-04-06:    ON: 0,  0:00:00,                  OFF: 0,  0:00:00
#                Total Count: 0                Total timing: 0:00:00
# ...

# %% [markdown]
# ## **_2) Heater_**

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
heater_on_count = {}
heater_off_count = {}

# Iterate through each row in the dataset
for index, row in cold1.iterrows():
    date = row['P_Date'].date()
    heater = row['Heater_1']
    
    # Increment count if heater state changes
    if index > 0:
        prev_heater = cold1.loc[index - 1, 'Heater_1']
        if heater != prev_heater:
            if heater == 1:
                heater_on_count[date] = heater_on_count.get(date, 0) + 1
            else:
                heater_off_count[date] = heater_off_count.get(date, 0) + 1

# Print count of heater ON and OFF for each date
for date, count in heater_on_count.items():
    off_count = heater_off_count.get(date, 0)
    print(f"{date}:  ON:   {count},            OFF:  {off_count},          Total: {count + off_count}")


# Convert dictionaries to lists for plotting
dates = list(heater_on_count.keys())
on_counts = list(heater_on_count.values())
off_counts = [heater_off_count.get(date, 0) for date in dates]

# Plotting
plt.figure(figsize=(15, 5))
plt.bar(dates, on_counts, color='skyblue', label='Heater ON')
plt.bar(dates, off_counts, color='orange', bottom=on_counts, label='Heater OFF')
plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Heater ON/OFF Count for Each Date')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 2023-04-20:  ON:   1,            OFF:  1,          Total: 2
# 2023-05-10:  ON:   1,            OFF:  1,          Total: 2
# 2023-05-15:  ON:   1,            OFF:  1,          Total: 2
# 2023-05-18:  ON:   1,            OFF:  1,          Total: 2
# 2023-05-19:  ON:   2,            OFF:  2,          Total: 4
# 2023-05-20:  ON:   2,            OFF:  2,          Total: 4
# 2023-05-25:  ON:   1,            OFF:  1,          Total: 2
# 2023-05-26:  ON:   1,            OFF:  1,          Total: 2
# 2023-05-27:  ON:   1,            OFF:  1,          Total: 2
# 2023-05-28:  ON:   2,            OFF:  2,          Total: 4
# 2023-05-29:  ON:   2,            OFF:  2,          Total: 4
# 2023-06-06:  ON:   1,            OFF:  0,          Total: 1
# 2023-06-08:  ON:   2,            OFF:  3,          Total: 5
# 2023-06-11:  ON:   1,            OFF:  1,          Total: 2
# 2023-06-24:  ON:   1,            OFF:  0,          Total: 1
# 2023-06-30:  ON:   1,            OFF:  1,          Total: 2
# ...

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Initialize lists to store room temperature and humidity data
room_temp_dates = []
room_temp_values = []
room_hum_values = []

# Iterate through each row in the dataset
for index, row in cold1.iterrows():
    date = row['P_Date'].date()
    heater = row['Heater_1']
    
    # Increment count if heater state changes
    if index > 0:
        prev_heater = cold1.loc[index - 1, 'Heater_1']
        if heater != prev_heater:
            if heater == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1
    
    # Store room temperature and humidity data
    room_temp_dates.append(date)
    room_temp_values.append(row['Room_Temp'])
    room_hum_values.append(row['Room_Hum'])

# Convert dictionaries to lists for plotting
dates = list(solenoid_on_count.keys())
on_counts = list(solenoid_on_count.values())
off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 8))
ax2 = ax1.twinx()

# Plot heater ON/OFF counts
ax1.bar(dates, on_counts, color='skyblue', label='Heater ON')
ax1.bar(dates, off_counts, color='orange', bottom=on_counts, label='Heater OFF')
ax1.set_xlabel('Date')
ax1.set_ylabel('Count')
ax1.set_title('Heater ON/OFF Count, Room Temperature, and Room Humidity')
ax1.legend(loc='upper left')
ax1.tick_params(axis='x', rotation=45)

# Plot room temperature
ax2.plot(room_temp_dates, room_temp_values, color='red', linestyle='-', label='Room Temp')
ax2.plot(room_temp_dates, room_hum_values, color='blue', linestyle='-', label='Room Humidity')
ax2.set_ylabel('Temperature/Humidity')
ax2.set_ylim(0, 100)
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
from datetime import datetime, timedelta

# Initialize dictionaries to track time for each state
heater_on_time = {}
heater_off_time = {}

# Initialize dictionaries to track count of ON and OFF switches for each date
heater_on_count = {}
heater_off_count = {}

# Iterate through each row in the dataset
for index, row in cold1.iterrows():
    date = row['P_Date'].date()
    heater = row['Heater_1']
    timestamp = row['P_Date']
    
    # Initialize time if not present
    if date not in heater_on_time:
        heater_on_time[date] = timedelta()
    if date not in heater_off_time:
        heater_off_time[date] = timedelta()
    
    # Initialize count if not present
    if date not in heater_on_count:
        heater_on_count[date] = 0
    if date not in heater_off_count:
        heater_off_count[date] = 0
    
    # Increment count if heater state changes
    if index > 0:
        prev_heater = cold1.loc[index - 1, 'Heater_1']
        prev_timestamp = cold1.loc[index - 1, 'P_Date']
        
        if heater != prev_heater:
            time_diff = timestamp - prev_timestamp
            if heater == 1:
                heater_on_time[date] += time_diff
                heater_on_count[date] += 1
            else:
                heater_off_time[date] += time_diff
                heater_off_count[date] += 1

# Print count of heater ON and OFF for each date
for date, count in heater_on_count.items():
    off_count = heater_off_count.get(date, 0)
    print(f"{date}:    ON: {count},  {heater_on_time[date]},                   OFF: {off_count},  {heater_off_time[date]}                Total Count: {count + off_count}                Total timing: {heater_on_time[date] + heater_off_time[date]}")

# Print total time ON and OFF for each date
for date, time_on in heater_on_time.items():
    time_off = heater_off_time[date]
    total_time_on = time_on.total_seconds()
    total_time_off = time_off.total_seconds()
    total_time = total_time_on + total_time_off
# Out:
# 2023-04-01:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-02:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-03:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-04:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-05:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-06:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-07:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# ...

# %%
from datetime import datetime, timedelta

# Initialize dictionaries to track time for each state
heater_on_time = {}
heater_off_time = {}

# Initialize dictionaries to track count of ON and OFF switches for each date
heater_on_count = {}
heater_off_count = {}

# Iterate through each row in the dataset
for index, row in cold1.iterrows():
    date = row['P_Date'].date()
    heater = row['Heater_1']
    timestamp = row['P_Date']
    
    # Initialize time if not present
    if date not in heater_on_time:
        heater_on_time[date] = timedelta()
    if date not in heater_off_time:
        heater_off_time[date] = timedelta()
    
    # Initialize count if not present
    if date not in heater_on_count:
        heater_on_count[date] = 0
    if date not in heater_off_count:
        heater_off_count[date] = 0
    
    # Increment count if heater state changes
    if index > 0:
        prev_heater = cold1.loc[index - 1, 'Heater_1']
        prev_timestamp = cold1.loc[index - 1, 'P_Date']
        
        if heater != prev_heater:
            time_diff = timestamp - prev_timestamp
            if heater == 1:
                heater_on_time[date] += time_diff
                heater_on_count[date] += 1
            else:
                heater_off_time[date] += time_diff
                heater_off_count[date] += 1

# Print count of heater ON and OFF for each date
for date, count in heater_on_count.items():
    off_count = heater_off_count.get(date, 0)
    if count != 0 or off_count != 0:
        print(f"{date}:    ON: {count},  {heater_on_time[date]},                   OFF: {off_count},  {heater_off_time[date]}                Total Count: {count + off_count}                Total timing: {heater_on_time[date] + heater_off_time[date]}")

# Print total time ON and OFF for each date
for date, time_on in heater_on_time.items():
    time_off = heater_off_time[date]
    total_time_on = time_on.total_seconds()
    total_time_off = time_off.total_seconds()
    total_time = total_time_on + total_time_off


# Extract dates and total time ON and OFF from dictionaries
dates = list(heater_on_time.keys())
total_time_on = [heater_on_time[date].total_seconds() / 3600 for date in dates]  # Convert to hours
total_time_off = [heater_off_time[date].total_seconds() / 3600 for date in dates]  # Convert to hours

# Plotting
plt.figure(figsize=(25, 6))
plt.plot(dates, total_time_on, marker='o', linestyle='-', label='Total Time ON')
plt.plot(dates, total_time_off, marker='o', linestyle='-', label='Total Time OFF')
plt.title('Total Heater ON and OFF Time Over Time')
plt.xlabel('Date')
plt.ylabel('Total Time (hours)')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 2023-04-20:    ON: 1,  0 days 21:58:06,                   OFF: 1,  0 days 00:05:18                Total Count: 2                Total timing: 0 days 22:03:24
# 2023-05-10:    ON: 1,  0 days 00:05:10,                   OFF: 1,  0 days 01:27:49                Total Count: 2                Total timing: 0 days 01:32:59
# 2023-05-15:    ON: 1,  1 days 21:15:30,                   OFF: 1,  0 days 00:07:14                Total Count: 2                Total timing: 1 days 21:22:44
# 2023-05-18:    ON: 1,  0 days 00:05:10,                   OFF: 1,  0 days 00:05:10                Total Count: 2                Total timing: 0 days 00:10:20
# 2023-05-19:    ON: 2,  0 days 00:10:22,                   OFF: 2,  0 days 00:10:00                Total Count: 4                Total timing: 0 days 00:20:22
# 2023-05-20:    ON: 2,  0 days 00:10:11,                   OFF: 2,  0 days 00:34:11                Total Count: 4                Total timing: 0 days 00:44:22
# ...

# %% [markdown]
# ### **_Heater and solenoid combined_**

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
heater_on_count = {}
heater_off_count = {}
solenoid_on_count = {}
solenoid_off_count = {}

# Iterate through each row in the dataset
for index, row in cold1.iterrows():
    date = row['P_Date'].date()
    heater = row['Heater_1']
    solenoid = row['Solenoid']
    
    # Increment count if heater state changes
    if index > 0:
        prev_heater = cold1.loc[index - 1, 'Heater_1']
        if heater != prev_heater:
            if heater == 1:
                heater_on_count[date] = heater_on_count.get(date, 0) + 1
            else:
                heater_off_count[date] = heater_off_count.get(date, 0) + 1
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold1.loc[index - 1, 'Solenoid']
        if solenoid != prev_solenoid:
            if solenoid == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1

# Get common dates for both heater and solenoid data
common_dates = set(heater_on_count.keys()).intersection(solenoid_on_count.keys())

# Convert dictionaries to lists for plotting
dates = list(common_dates)
index = np.arange(len(dates))

heater_on_counts = [heater_on_count[date] for date in dates]
heater_off_counts = [heater_off_count.get(date, 0) for date in dates]

solenoid_on_counts = [solenoid_on_count[date] for date in dates]
solenoid_off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
bar_width = 0.35

plt.figure(figsize=(15, 5))

plt.bar(index, heater_on_counts, bar_width, color='skyblue', label='Heater ON')
plt.bar(index + bar_width, solenoid_on_counts, bar_width, color='green', label='Solenoid ON')

plt.bar(index, heater_off_counts, bar_width, color='orange', label='Heater OFF', bottom=heater_on_counts)
plt.bar(index + bar_width, solenoid_off_counts, bar_width, color='yellow', label='Solenoid OFF', bottom=solenoid_on_counts)

plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Heater and Solenoid ON/OFF Count for Each Date')
plt.xticks(index + bar_width / 2, dates, rotation=45)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **_3) Fans 1, 2, 3, 4_**

# %%
# Initialize dictionaries to track count of ON and OFF switches for each fan on each date
fan_on_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}
fan_off_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}

# Get unique dates from the dataset
unique_dates = set(cold1['P_Date'].dt.date)

# Iterate through each unique date
for date in unique_dates:
    print(f"Date: {date}")
    
    # Iterate through each fan
    for fan_num in range(1, 5):
        fan_name = f'Fan_{fan_num}'
        fan_state = cold1.loc[cold1['P_Date'].dt.date == date, fan_name].values
        
        # Get previous state of the fan
        prev_fan_state = cold1.loc[cold1['P_Date'].dt.date == date, fan_name].shift().values
        prev_fan_state[0] = 0  
        
        # Count ON and OFF switches for the current date
        on_count = sum((fan_state == 1) & (prev_fan_state == 0))
        off_count = sum((fan_state == 0) & (prev_fan_state == 1))
        
        # Update counts in the dictionaries
        fan_on_count[fan_name][date] = on_count
        fan_off_count[fan_name][date] = off_count
        
        # Display fan status for the current date
        total_count = on_count + off_count
        print(f"    {fan_name}: ON: {on_count}, OFF: {off_count}, Total: {total_count}")

    print()
# Out:
# Date: 2023-04-08
#     Fan_1: ON: 0, OFF: 0, Total: 0
#     Fan_2: ON: 0, OFF: 0, Total: 0
#     Fan_3: ON: 0, OFF: 0, Total: 0
#     Fan_4: ON: 0, OFF: 0, Total: 0
#
# Date: 2023-07-12
#     Fan_1: ON: 1, OFF: 0, Total: 1
#     Fan_2: ON: 1, OFF: 0, Total: 1
#     Fan_3: ON: 1, OFF: 0, Total: 1
#     Fan_4: ON: 1, OFF: 0, Total: 1
#
# Date: 2023-05-06
#     Fan_1: ON: 1, OFF: 0, Total: 1
#     Fan_2: ON: 1, OFF: 0, Total: 1
#     Fan_3: ON: 1, OFF: 0, Total: 1
#     Fan_4: ON: 1, OFF: 0, Total: 1
#
# Date: 2023-06-22
#     Fan_1: ON: 1, OFF: 0, Total: 1
#     Fan_2: ON: 1, OFF: 0, Total: 1
#     Fan_3: ON: 1, OFF: 0, Total: 1
#     Fan_4: ON: 1, OFF: 0, Total: 1
#
# Date: 2023-04-05
#     Fan_1: ON: 3, OFF: 3, Total: 6
#     Fan_2: ON: 3, OFF: 3, Total: 6
#     Fan_3: ON: 3, OFF: 3, Total: 6
#     Fan_4: ON: 3, OFF: 3, Total: 6
#
# Date: 2023-05-13
#     Fan_1: ON: 1, OFF: 0, Total: 1
#     Fan_2: ON: 1, OFF: 0, Total: 1
#     Fan_3: ON: 1, OFF: 0, Total: 1
# ...

# %%
# Initialize dictionaries to track count of ON and OFF switches for each fan on each date
fan_on_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}
fan_off_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}

# Get unique dates from the dataset
unique_dates = sorted(set(cold1['P_Date'].dt.date))

# Iterate through each unique date
for date in unique_dates:
    # Iterate through each fan
    for fan_num in range(1, 5):
        fan_name = f'Fan_{fan_num}'
        fan_state = cold1.loc[cold1['P_Date'].dt.date == date, fan_name].values
        
        # Get previous state of the fan
        prev_fan_state = cold1.loc[cold1['P_Date'].dt.date == date, fan_name].shift().values
        prev_fan_state[0] = 0  # For the first row, set previous state to 0
        
        # Count ON and OFF switches for the current date
        on_count = sum((fan_state == 1) & (prev_fan_state == 0))
        off_count = sum((fan_state == 0) & (prev_fan_state == 1))
        
        # Update counts in the dictionaries
        fan_on_count[fan_name][date] = on_count
        fan_off_count[fan_name][date] = off_count

# Plotting the grouped bar plot
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
axes = axes.ravel()

bar_width = 0.35
index = range(len(unique_dates))

for i, fan_name in enumerate(fan_on_count.keys()):
    dates = list(unique_dates)
    on_counts = [fan_on_count[fan_name][date] for date in dates]
    off_counts = [fan_off_count[fan_name][date] for date in dates]

    axes[i].bar(index, on_counts, bar_width, label='ON', color='grey', align='center')
    axes[i].bar(index, off_counts, bar_width, label='OFF', color='black', align='center', bottom=on_counts)
    
    axes[i].set_xlabel('Date')
    axes[i].set_ylabel('Count')
    axes[i].set_title(fan_name)
    axes[i].legend()

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Initialize dictionaries to track count of ON and OFF switches for each fan on each date
fan_on_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}
fan_off_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}

# Get unique dates from the dataset
unique_dates = sorted(set(cold1['P_Date'].dt.date))

# Iterate through each unique date
for date in unique_dates:
    # Iterate through each fan
    for fan_num in range(1, 5):
        fan_name = f'Fan_{fan_num}'
        fan_state = cold1.loc[cold1['P_Date'].dt.date == date, fan_name].values
        
        # Get previous state of the fan
        prev_fan_state = cold1.loc[cold1['P_Date'].dt.date == date, fan_name].shift().values
        prev_fan_state[0] = 0  # For the first row, set previous state to 0
        
        # Count ON and OFF switches for the current date
        on_count = sum((fan_state == 1) & (prev_fan_state == 0))
        off_count = sum((fan_state == 0) & (prev_fan_state == 1))
        
        # Update counts in the dictionaries
        fan_on_count[fan_name][date] = on_count
        fan_off_count[fan_name][date] = off_count

# Plotting the graph
fig, axes = plt.subplots(2, 2, figsize=(25, 10))
axes = axes.ravel()

for i, fan_name in enumerate(fan_on_count.keys()):
    dates = list(unique_dates)
    on_counts = [fan_on_count[fan_name][date] for date in dates]
    off_counts = [fan_off_count[fan_name][date] for date in dates]
    # total_counts = [on + off for on, off in zip(on_counts, off_counts)]

    axes[i].plot(dates, on_counts, label='ON', color= 'grey')
    axes[i].plot(dates, off_counts, label='OFF', color= 'black')
    # axes[i].plot(dates, total_counts, label='Total')
    axes[i].set_title(fan_name)
    axes[i].legend()

# Set common labels
fig.text(0.5, 0.04, 'Date', ha='center', va='center')
fig.text(0.06, 0.5, 'Count', ha='center', va='center', rotation='vertical')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **<mark>ROOM 2</mark>**

# %%
cold2 = cold[['P_ID', 'P_Date', 'Room', 'Solenoid', 'Room_Temp', 'Temp_Avg', 'Room_Hum', 'Humidity_Avg', 'Heater_1', 'Fan_1', 'Fan_2', 'Fan_3', 'Fan_4']]
cold2 = cold2[cold2["Room"]=="Room-2"].reset_index(drop=True)
cold2
# Out:
#          P_ID              P_Date    Room  Solenoid  Room_Temp  Temp_Avg  \
# 0     4601354 2023-04-01 09:29:30  Room-2         1       17.6      26.0
# 1     4601374 2023-04-01 09:34:40  Room-2         1       17.6       0.0
# 2     4601395 2023-04-01 09:39:51  Room-2         1       17.6       0.0
# 3     4601413 2023-04-01 09:45:05  Room-2         1       17.6       0.0
# 4     4601434 2023-04-01 09:50:10  Room-2         1       17.6       0.0
# ...       ...                 ...     ...       ...        ...       ...
# 4999  4821970 2023-07-03 15:55:59  Room-2         0       27.4       0.0
# 5000  4821976 2023-07-03 15:57:45  Room-2         0       27.3       0.0
# 5001  4821992 2023-07-03 16:02:55  Room-2         0       27.4       0.0
# 5002  4822005 2023-07-03 16:08:04  Room-2         0       27.5       0.0
# 5003  4822020 2023-07-03 16:13:17  Room-2         0       27.4       0.0
#
#       Room_Hum  Humidity_Avg  Heater_1  Fan_1  Fan_2  Fan_3  Fan_4
# ...

# %% [markdown]
# ## **_1) Solenoid Valve_**

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Iterate through each row in the dataset
for index, row in cold2.iterrows():
    date = row['P_Date'].date()
    solenoid = row['Solenoid']
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold2.loc[index - 1, 'Solenoid']
        if solenoid != prev_solenoid:
            if solenoid == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1

# Print count of solenoid ON and OFF for each date
for date, count in solenoid_on_count.items():
    off_count = solenoid_off_count.get(date, 0)
    print(f"{date}:  ON:   {count},            OFF:  {off_count},          Total: {count + off_count}")


# Convert dictionaries to lists for plotting
dates = list(solenoid_on_count.keys())
on_counts = list(solenoid_on_count.values())
off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
plt.figure(figsize=(15, 5))
plt.bar(dates, on_counts, color='green', label='Solenoid ON')
plt.bar(dates, off_counts, color='yellow', bottom=on_counts, label='Solenoid OFF')
plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Solenoid ON/OFF Count for Each Date')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 2023-04-01:  ON:   1,            OFF:  1,          Total: 2
# 2023-04-02:  ON:   3,            OFF:  3,          Total: 6
# 2023-04-03:  ON:   2,            OFF:  2,          Total: 4
# 2023-04-04:  ON:   3,            OFF:  3,          Total: 6
# 2023-04-05:  ON:   2,            OFF:  3,          Total: 5
# 2023-04-11:  ON:   2,            OFF:  1,          Total: 3
# 2023-04-19:  ON:   1,            OFF:  0,          Total: 1
# 2023-04-20:  ON:   1,            OFF:  2,          Total: 3
# 2023-04-22:  ON:   2,            OFF:  1,          Total: 3
# 2023-04-25:  ON:   2,            OFF:  1,          Total: 3
# 2023-04-27:  ON:   1,            OFF:  1,          Total: 2
# 2023-04-28:  ON:   1,            OFF:  1,          Total: 2
# 2023-05-04:  ON:   2,            OFF:  2,          Total: 4
# 2023-05-05:  ON:   2,            OFF:  2,          Total: 4
# 2023-05-07:  ON:   1,            OFF:  1,          Total: 2
# 2023-05-09:  ON:   1,            OFF:  1,          Total: 2
# ...

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Initialize lists to store room temperature data
room_temp_dates = []
room_temp_values = []

# Iterate through each row in the dataset
for index, row in cold2.iterrows():
    date = row['P_Date'].date()
    solenoid = row['Solenoid']
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold2.loc[index - 1, 'Solenoid']
        if solenoid != prev_solenoid:
            if solenoid == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1
    
    # Store room temperature data
    room_temp_dates.append(date)
    room_temp_values.append(row['Room_Temp'])

# Convert dictionaries to lists for plotting
dates = list(solenoid_on_count.keys())
on_counts = list(solenoid_on_count.values())
off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
fig, ax1 = plt.subplots(figsize=(15, 5))
ax2 = ax1.twinx()

# Plot solenoid ON/OFF counts
ax1.bar(dates, on_counts, color='green', label='Solenoid ON')
ax1.bar(dates, off_counts, color='yellow', bottom=on_counts, label='Solenoid OFF')
ax1.set_xlabel('Date')
ax1.set_ylabel('Count')
ax1.set_title('Solenoid ON/OFF Count and Room Temperature')
ax1.legend(loc='upper left')
ax1.tick_params(axis='x', rotation=45)

# Plot room temperature
ax2.plot(room_temp_dates, room_temp_values, color='red', linestyle='-', label='Room Temp')
ax2.set_ylabel('Room Temperature')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Initialize lists to store room humidity data
room_hum_dates = []
room_hum_values = []

# Iterate through each row in the dataset
for index, row in cold2.iterrows():
    date = row['P_Date'].date()
    solenoid = row['Solenoid']
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold2.loc[index - 1, 'Solenoid']
        if solenoid != prev_solenoid:
            if solenoid == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1
    
    # Store room humidity data
    room_hum_dates.append(date)
    room_hum_values.append(row['Room_Hum'])

# Convert dictionaries to lists for plotting
dates = list(solenoid_on_count.keys())
on_counts = list(solenoid_on_count.values())
off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
fig, ax1 = plt.subplots(figsize=(15, 6))
ax2 = ax1.twinx()

# Plot solenoid ON/OFF counts
ax1.bar(dates, on_counts, color='green', label='Solenoid ON')
ax1.bar(dates, off_counts, color='yellow', bottom=on_counts, label='Solenoid OFF')
ax1.set_xlabel('Date')
ax1.set_ylabel('Count')
ax1.set_title('Solenoid ON/OFF Count and Room Humidity')
ax1.legend(loc='upper left')
ax1.tick_params(axis='x', rotation=45)

# Plot room humidity
ax2.plot(room_hum_dates, room_hum_values, color='blue', linestyle='-', label='Room Hum')
ax2.set_ylabel('Room Humidity')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Initialize lists to store room temperature and humidity data
room_temp_dates = []
room_temp_values = []
room_hum_values = []

# Iterate through each row in the dataset
for index, row in cold2.iterrows():
    date = row['P_Date'].date()
    solenoid = row['Solenoid']
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold2.loc[index - 1, 'Solenoid']
        if solenoid != prev_solenoid:
            if solenoid == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1
    
    # Store room temperature and humidity data
    room_temp_dates.append(date)
    room_temp_values.append(row['Room_Temp'])
    room_hum_values.append(row['Room_Hum'])

# Convert dictionaries to lists for plotting
dates = list(solenoid_on_count.keys())
on_counts = list(solenoid_on_count.values())
off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 8))
ax2 = ax1.twinx()

# Plot solenoid ON/OFF counts
ax1.bar(dates, on_counts, color='green', label='Solenoid ON')
ax1.bar(dates, off_counts, color='yellow', bottom=on_counts, label='Solenoid OFF')
ax1.set_xlabel('Date')
ax1.set_ylabel('Count')
ax1.set_title('Solenoid ON/OFF Count, Room Temperature, and Room Humidity')
ax1.legend(loc='upper left')
ax1.tick_params(axis='x', rotation=45)

# Plot room temperature
ax2.plot(room_temp_dates, room_temp_values, color='red', linestyle='-', label='Room Temp')
ax2.plot(room_temp_dates, room_hum_values, color='blue', linestyle='-', label='Room Humidity')
ax2.set_ylabel('Value')
ax2.set_ylim(0, 100)
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
from datetime import datetime, timedelta

# Initialize dictionaries to track time for each state
solenoid_on_time = {}
solenoid_off_time = {}

# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Iterate through each row in the dataset
for index, row in cold2.iterrows():
    date = row['P_Date'].date()
    solenoid = row['Solenoid']
    timestamp = row['P_Date']
    
    # Initialize time if not present
    if date not in solenoid_on_time:
        solenoid_on_time[date] = timedelta()
    if date not in solenoid_off_time:
        solenoid_off_time[date] = timedelta()
    
    # Initialize count if not present
    if date not in solenoid_on_count:
        solenoid_on_count[date] = 0
    if date not in solenoid_off_count:
        solenoid_off_count[date] = 0
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold2.loc[index - 1, 'Solenoid']
        prev_timestamp = cold2.loc[index - 1, 'P_Date']
        
        if solenoid != prev_solenoid:
            time_diff = timestamp - prev_timestamp
            if solenoid == 1:
                solenoid_on_time[date] += time_diff
                solenoid_on_count[date] += 1
            else:
                solenoid_off_time[date] += time_diff
                solenoid_off_count[date] += 1

# Print count of solenoid ON and OFF for each date
for date, count in solenoid_on_count.items():
    off_count = solenoid_off_count.get(date, 0)
    print(f"{date}:    ON: {count},  {solenoid_on_time[date]},                  OFF: {off_count},  {solenoid_off_time[date]}")
    print (f"               Total Count: {count + off_count}                Total timing: {solenoid_on_time[date] + solenoid_off_time[date]}")


# Print total time ON and OFF for each date
for date, time_on in solenoid_on_time.items():
    time_off = solenoid_off_time[date]
    total_time_on = time_on.total_seconds()
    total_time_off = time_off.total_seconds()
    total_time = total_time_on + total_time_off


# Convert timedelta to seconds for plotting
time_on_seconds = {date: time.total_seconds() for date, time in solenoid_on_time.items()}
time_off_seconds = {date: time.total_seconds() for date, time in solenoid_off_time.items()}

# Plotting
plt.figure(figsize=(15, 6))
plt.plot(list(time_on_seconds.keys()), list(time_on_seconds.values()), label='Time ON', marker='o', color='Green')
plt.plot(list(time_off_seconds.keys()), list(time_off_seconds.values()), label='Time OFF', marker='o', color='yellow')
plt.title('Solenoid ON/OFF Time')
plt.xlabel('Date')
plt.ylabel('Time (seconds)')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 2023-04-01:    ON: 1,  0 days 00:05:09,                  OFF: 1,  0 days 00:05:09
#                Total Count: 2                Total timing: 0 days 00:10:18
# 2023-04-02:    ON: 3,  0 days 00:15:30,                  OFF: 3,  0 days 00:15:28
#                Total Count: 6                Total timing: 0 days 00:30:58
# 2023-04-03:    ON: 2,  0 days 00:10:18,                  OFF: 2,  0 days 00:10:22
#                Total Count: 4                Total timing: 0 days 00:20:40
# 2023-04-04:    ON: 3,  0 days 00:15:24,                  OFF: 3,  0 days 00:15:34
#                Total Count: 6                Total timing: 0 days 00:30:58
# 2023-04-05:    ON: 2,  0 days 00:10:18,                  OFF: 3,  0 days 05:16:03
#                Total Count: 5                Total timing: 0 days 05:26:21
# 2023-04-06:    ON: 0,  0:00:00,                  OFF: 0,  0:00:00
#                Total Count: 0                Total timing: 0:00:00
# ...

# %% [markdown]
# ## **_2) Heater_**

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
heater_on_count = {}
heater_off_count = {}

# Iterate through each row in the dataset
for index, row in cold2.iterrows():
    date = row['P_Date'].date()
    heater = row['Heater_1']
    
    # Increment count if heater state changes
    if index > 0:
        prev_heater = cold2.loc[index - 1, 'Heater_1']
        if heater != prev_heater:
            if heater == 1:
                heater_on_count[date] = heater_on_count.get(date, 0) + 1
            else:
                heater_off_count[date] = heater_off_count.get(date, 0) + 1

# Print count of heater ON and OFF for each date
for date, count in heater_on_count.items():
    off_count = heater_off_count.get(date, 0)
    print(f"{date}:  ON:   {count},            OFF:  {off_count},          Total: {count + off_count}")

# Convert dictionaries to lists for plotting
dates = list(heater_on_count.keys())
on_counts = list(heater_on_count.values())
off_counts = [heater_off_count.get(date, 0) for date in dates]

# Plotting
plt.figure(figsize=(15, 5))
plt.bar(dates, on_counts, color='skyblue', label='Heater ON')
plt.bar(dates, off_counts, color='orange', bottom=on_counts, label='Heater OFF')
plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Heater ON/OFF Count for Each Date')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 2023-04-20:  ON:   1,            OFF:  1,          Total: 2
# 2023-04-22:  ON:   2,            OFF:  1,          Total: 3
# 2023-05-10:  ON:   2,            OFF:  1,          Total: 3
# 2023-05-11:  ON:   2,            OFF:  3,          Total: 5
# 2023-05-13:  ON:   2,            OFF:  2,          Total: 4
# 2023-05-15:  ON:   5,            OFF:  5,          Total: 10
# 2023-05-16:  ON:   1,            OFF:  1,          Total: 2
# 2023-05-17:  ON:   2,            OFF:  1,          Total: 3
# 2023-05-19:  ON:   1,            OFF:  1,          Total: 2
# 2023-05-20:  ON:   2,            OFF:  2,          Total: 4
# 2023-05-23:  ON:   1,            OFF:  1,          Total: 2
# 2023-05-24:  ON:   2,            OFF:  1,          Total: 3
# 2023-05-25:  ON:   3,            OFF:  3,          Total: 6
# 2023-05-26:  ON:   1,            OFF:  1,          Total: 2
# 2023-05-27:  ON:   2,            OFF:  2,          Total: 4
# 2023-05-29:  ON:   1,            OFF:  2,          Total: 3
# ...

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Initialize lists to store room temperature and humidity data
room_temp_dates = []
room_temp_values = []
room_hum_values = []

# Iterate through each row in the dataset
for index, row in cold2.iterrows():
    date = row['P_Date'].date()
    heater = row['Heater_1']
    
    # Increment count if heater state changes
    if index > 0:
        prev_heater = cold2.loc[index - 1, 'Heater_1']
        if heater != prev_heater:
            if heater == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1
    
    # Store room temperature and humidity data
    room_temp_dates.append(date)
    room_temp_values.append(row['Room_Temp'])
    room_hum_values.append(row['Room_Hum'])

# Convert dictionaries to lists for plotting
dates = list(solenoid_on_count.keys())
on_counts = list(solenoid_on_count.values())
off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 8))
ax2 = ax1.twinx()

# Plot heater ON/OFF counts
ax1.bar(dates, on_counts, color='skyblue', label='Heater ON')
ax1.bar(dates, off_counts, color='orange', bottom=on_counts, label='Heater OFF')
ax1.set_xlabel('Date')
ax1.set_ylabel('Count')
ax1.set_title('Heater ON/OFF Count, Room Temperature, and Room Humidity')
ax1.legend(loc='upper left')
ax1.tick_params(axis='x', rotation=45)

# Plot room temperature
ax2.plot(room_temp_dates, room_temp_values, color='red', linestyle='-', label='Room Temp')
ax2.plot(room_temp_dates, room_hum_values, color='blue', linestyle='-', label='Room Humidity')
ax2.set_ylabel('Temperature/Humidity')
ax2.set_ylim(0, 100)
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
from datetime import datetime, timedelta

# Initialize dictionaries to track time for each state
heater_on_time = {}
heater_off_time = {}

# Initialize dictionaries to track count of ON and OFF switches for each date
heater_on_count = {}
heater_off_count = {}

# Iterate through each row in the dataset
for index, row in cold2.iterrows():
    date = row['P_Date'].date()
    heater = row['Heater_1']
    timestamp = row['P_Date']
    
    # Initialize time if not present
    if date not in heater_on_time:
        heater_on_time[date] = timedelta()
    if date not in heater_off_time:
        heater_off_time[date] = timedelta()
    
    # Initialize count if not present
    if date not in heater_on_count:
        heater_on_count[date] = 0
    if date not in heater_off_count:
        heater_off_count[date] = 0
    
    # Increment count if heater state changes
    if index > 0:
        prev_heater = cold2.loc[index - 1, 'Heater_1']
        prev_timestamp = cold2.loc[index - 1, 'P_Date']
        
        if heater != prev_heater:
            time_diff = timestamp - prev_timestamp
            if heater == 1:
                heater_on_time[date] += time_diff
                heater_on_count[date] += 1
            else:
                heater_off_time[date] += time_diff
                heater_off_count[date] += 1

# Print count of heater ON and OFF for each date
for date, count in heater_on_count.items():
    off_count = heater_off_count.get(date, 0)
    print(f"{date}:    ON: {count},  {heater_on_time[date]},                   OFF: {off_count},  {heater_off_time[date]}                Total Count: {count + off_count}                Total timing: {heater_on_time[date] + heater_off_time[date]}")

# Print total time ON and OFF for each date
for date, time_on in heater_on_time.items():
    time_off = heater_off_time[date]
    total_time_on = time_on.total_seconds()
    total_time_off = time_off.total_seconds()
    total_time = total_time_on + total_time_off
# Out:
# 2023-04-01:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-02:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-03:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-04:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-05:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-06:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-07:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# ...

# %%
from datetime import datetime, timedelta

# Initialize dictionaries to track time for each state
heater_on_time = {}
heater_off_time = {}

# Initialize dictionaries to track count of ON and OFF switches for each date
heater_on_count = {}
heater_off_count = {}

# Iterate through each row in the dataset
for index, row in cold2.iterrows():
    date = row['P_Date'].date()
    heater = row['Heater_1']
    timestamp = row['P_Date']
    
    # Initialize time if not present
    if date not in heater_on_time:
        heater_on_time[date] = timedelta()
    if date not in heater_off_time:
        heater_off_time[date] = timedelta()
    
    # Initialize count if not present
    if date not in heater_on_count:
        heater_on_count[date] = 0
    if date not in heater_off_count:
        heater_off_count[date] = 0
    
    # Increment count if heater state changes
    if index > 0:
        prev_heater = cold2.loc[index - 1, 'Heater_1']
        prev_timestamp = cold2.loc[index - 1, 'P_Date']
        
        if heater != prev_heater:
            time_diff = timestamp - prev_timestamp
            if heater == 1:
                heater_on_time[date] += time_diff
                heater_on_count[date] += 1
            else:
                heater_off_time[date] += time_diff
                heater_off_count[date] += 1

# Print count of heater ON and OFF for each date
for date, count in heater_on_count.items():
    off_count = heater_off_count.get(date, 0)
    if count != 0 or off_count != 0:
        print(f"{date}:    ON: {count},  {heater_on_time[date]},                   OFF: {off_count},  {heater_off_time[date]}                Total Count: {count + off_count}                Total timing: {heater_on_time[date] + heater_off_time[date]}")

# Print total time ON and OFF for each date
for date, time_on in heater_on_time.items():
    time_off = heater_off_time[date]
    total_time_on = time_on.total_seconds()
    total_time_off = time_off.total_seconds()
    total_time = total_time_on + total_time_off


# Extract dates and total time ON and OFF from dictionaries
dates = list(heater_on_time.keys())
total_time_on = [heater_on_time[date].total_seconds() / 3600 for date in dates]  # Convert to hours
total_time_off = [heater_off_time[date].total_seconds() / 3600 for date in dates]  # Convert to hours

# Plotting
plt.figure(figsize=(25, 6))
plt.plot(dates, total_time_on, marker='o', linestyle='-', label='Total Time ON')
plt.plot(dates, total_time_off, marker='o', linestyle='-', label='Total Time OFF')
plt.title('Total Heater ON and OFF Time Over Time')
plt.xlabel('Date')
plt.ylabel('Total Time (hours)')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 2023-04-20:    ON: 1,  0 days 00:05:09,                   OFF: 1,  0 days 00:05:09                Total Count: 2                Total timing: 0 days 00:10:18
# 2023-04-22:    ON: 2,  1 days 21:29:36,                   OFF: 1,  0 days 00:07:41                Total Count: 3                Total timing: 1 days 21:37:17
# 2023-04-24:    ON: 0,  0:00:00,                   OFF: 1,  2 days 01:01:45                Total Count: 1                Total timing: 2 days 01:01:45
# 2023-05-10:    ON: 2,  0 days 00:10:17,                   OFF: 1,  0 days 01:06:56                Total Count: 3                Total timing: 0 days 01:17:13
# 2023-05-11:    ON: 2,  0 days 00:10:20,                   OFF: 3,  0 days 00:15:45                Total Count: 5                Total timing: 0 days 00:26:05
# 2023-05-13:    ON: 2,  0 days 00:10:18,                   OFF: 2,  0 days 04:49:46                Total Count: 4                Total timing: 0 days 05:00:04
# ...

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
heater_on_count = {}
heater_off_count = {}
solenoid_on_count = {}
solenoid_off_count = {}

# Iterate through each row in the dataset
for index, row in cold2.iterrows():
    date = row['P_Date'].date()
    heater = row['Heater_1']
    solenoid = row['Solenoid']
    
    # Increment count if heater state changes
    if index > 0:
        prev_heater = cold2.loc[index - 1, 'Heater_1']
        if heater != prev_heater:
            if heater == 1:
                heater_on_count[date] = heater_on_count.get(date, 0) + 1
            else:
                heater_off_count[date] = heater_off_count.get(date, 0) + 1
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold2.loc[index - 1, 'Solenoid']
        if solenoid != prev_solenoid:
            if solenoid == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1

# Get common dates for both heater and solenoid data
common_dates = set(heater_on_count.keys()).intersection(solenoid_on_count.keys())

# Convert dictionaries to lists for plotting
dates = list(common_dates)
index = np.arange(len(dates))

heater_on_counts = [heater_on_count[date] for date in dates]
heater_off_counts = [heater_off_count.get(date, 0) for date in dates]

solenoid_on_counts = [solenoid_on_count[date] for date in dates]
solenoid_off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
bar_width = 0.35

plt.figure(figsize=(15, 5))

plt.bar(index, heater_on_counts, bar_width, color='skyblue', label='Heater ON')
plt.bar(index + bar_width, solenoid_on_counts, bar_width, color='green', label='Solenoid ON')

plt.bar(index, heater_off_counts, bar_width, color='orange', label='Heater OFF', bottom=heater_on_counts)
plt.bar(index + bar_width, solenoid_off_counts, bar_width, color='yellow', label='Solenoid OFF', bottom=solenoid_on_counts)

plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Heater and Solenoid ON/OFF Count for Each Date')
plt.xticks(index + bar_width / 2, dates, rotation=45)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **_3) Fans 1, 2, 3, 4_**

# %%
# Initialize dictionaries to track count of ON and OFF switches for each fan on each date
fan_on_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}
fan_off_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}

# Get unique dates from the dataset
unique_dates = set(cold2['P_Date'].dt.date)

# Iterate through each unique date
for date in unique_dates:
    print(f"Date: {date}")
    
    # Iterate through each fan
    for fan_num in range(1, 5):
        fan_name = f'Fan_{fan_num}'
        fan_state = cold2.loc[cold2['P_Date'].dt.date == date, fan_name].values
        
        # Get previous state of the fan
        prev_fan_state = cold2.loc[cold2['P_Date'].dt.date == date, fan_name].shift().values
        prev_fan_state[0] = 0  
        
        # Count ON and OFF switches for the current date
        on_count = sum((fan_state == 1) & (prev_fan_state == 0))
        off_count = sum((fan_state == 0) & (prev_fan_state == 1))
        
        # Update counts in the dictionaries
        fan_on_count[fan_name][date] = on_count
        fan_off_count[fan_name][date] = off_count
        
        # Display fan status for the current date
        total_count = on_count + off_count
        print(f"    {fan_name}: ON: {on_count}, OFF: {off_count}, Total: {total_count}")

    print()
# Out:
# Date: 2023-04-08
#     Fan_1: ON: 0, OFF: 0, Total: 0
#     Fan_2: ON: 0, OFF: 0, Total: 0
#     Fan_3: ON: 0, OFF: 0, Total: 0
#     Fan_4: ON: 0, OFF: 0, Total: 0
#
# Date: 2023-05-06
#     Fan_1: ON: 1, OFF: 0, Total: 1
#     Fan_2: ON: 1, OFF: 0, Total: 1
#     Fan_3: ON: 1, OFF: 0, Total: 1
#     Fan_4: ON: 1, OFF: 0, Total: 1
#
# Date: 2023-06-22
#     Fan_1: ON: 1, OFF: 0, Total: 1
#     Fan_2: ON: 1, OFF: 0, Total: 1
#     Fan_3: ON: 1, OFF: 0, Total: 1
#     Fan_4: ON: 1, OFF: 0, Total: 1
#
# Date: 2023-04-05
#     Fan_1: ON: 2, OFF: 2, Total: 4
#     Fan_2: ON: 2, OFF: 2, Total: 4
#     Fan_3: ON: 2, OFF: 2, Total: 4
#     Fan_4: ON: 3, OFF: 3, Total: 6
#
# Date: 2023-05-13
#     Fan_1: ON: 2, OFF: 1, Total: 3
#     Fan_2: ON: 2, OFF: 1, Total: 3
#     Fan_3: ON: 2, OFF: 1, Total: 3
#     Fan_4: ON: 2, OFF: 1, Total: 3
#
# Date: 2023-05-12
#     Fan_1: ON: 4, OFF: 3, Total: 7
#     Fan_2: ON: 4, OFF: 3, Total: 7
#     Fan_3: ON: 4, OFF: 3, Total: 7
# ...

# %%
# Initialize dictionaries to track count of ON and OFF switches for each fan on each date
fan_on_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}
fan_off_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}

# Get unique dates from the dataset
unique_dates = sorted(set(cold2['P_Date'].dt.date))

# Iterate through each unique date
for date in unique_dates:
    # Iterate through each fan
    for fan_num in range(1, 5):
        fan_name = f'Fan_{fan_num}'
        fan_state = cold2.loc[cold2['P_Date'].dt.date == date, fan_name].values
        
        # Get previous state of the fan
        prev_fan_state = cold2.loc[cold2['P_Date'].dt.date == date, fan_name].shift().values
        prev_fan_state[0] = 0  # For the first row, set previous state to 0
        
        # Count ON and OFF switches for the current date
        on_count = sum((fan_state == 1) & (prev_fan_state == 0))
        off_count = sum((fan_state == 0) & (prev_fan_state == 1))
        
        # Update counts in the dictionaries
        fan_on_count[fan_name][date] = on_count
        fan_off_count[fan_name][date] = off_count

# Plotting the grouped bar plot
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
axes = axes.ravel()

bar_width = 0.35
index = range(len(unique_dates))

for i, fan_name in enumerate(fan_on_count.keys()):
    dates = list(unique_dates)
    on_counts = [fan_on_count[fan_name][date] for date in dates]
    off_counts = [fan_off_count[fan_name][date] for date in dates]

    axes[i].bar(index, on_counts, bar_width, label='ON', color='grey', align='center')
    axes[i].bar(index, off_counts, bar_width, label='OFF', color='black', align='center', bottom=on_counts)
    
    axes[i].set_xlabel('Date')
    axes[i].set_ylabel('Count')
    axes[i].set_title(fan_name)
    axes[i].legend()

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Initialize dictionaries to track count of ON and OFF switches for each fan on each date
fan_on_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}
fan_off_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}

# Get unique dates from the dataset
unique_dates = sorted(set(cold2['P_Date'].dt.date))

# Iterate through each unique date
for date in unique_dates:
    # Iterate through each fan
    for fan_num in range(1, 5):
        fan_name = f'Fan_{fan_num}'
        fan_state = cold2.loc[cold2['P_Date'].dt.date == date, fan_name].values
        
        # Get previous state of the fan
        prev_fan_state = cold2.loc[cold2['P_Date'].dt.date == date, fan_name].shift().values
        prev_fan_state[0] = 0  
        
        # Count ON and OFF switches for the current date
        on_count = sum((fan_state == 1) & (prev_fan_state == 0))
        off_count = sum((fan_state == 0) & (prev_fan_state == 1))
        
        # Update counts in the dictionaries
        fan_on_count[fan_name][date] = on_count
        fan_off_count[fan_name][date] = off_count

# Plotting the graph
fig, axes = plt.subplots(2, 2, figsize=(25, 8))
axes = axes.ravel()

for i, fan_name in enumerate(fan_on_count.keys()):
    dates = list(unique_dates)
    on_counts = [fan_on_count[fan_name][date] for date in dates]
    off_counts = [fan_off_count[fan_name][date] for date in dates]
    # total_counts = [on + off for on, off in zip(on_counts, off_counts)]

    axes[i].plot(dates, on_counts, label='ON', color= 'grey')
    axes[i].plot(dates, off_counts, label='OFF', color= 'black')
    # axes[i].plot(dates, total_counts, label='Total')
    axes[i].set_title(fan_name)
    axes[i].legend()

# Set common labels
fig.text(0.5, 0.04, 'Date', ha='center', va='center')
fig.text(0.06, 0.5, 'Count', ha='center', va='center', rotation='vertical')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **<mark>ROOM 3</mark>**

# %%
cold3 = cold[['P_ID', 'P_Date', 'Room', 'Solenoid', 'Room_Temp', 'Temp_Avg', 'Room_Hum', 'Humidity_Avg', 'Heater_1', 'Fan_1', 'Fan_2', 'Fan_3', 'Fan_4']]
cold3 = cold3[cold3["Room"]=="Room-3"].reset_index(drop=True)
cold3
# Out:
#          P_ID              P_Date    Room  Solenoid  Room_Temp  Temp_Avg  \
# 0     4599603 2023-04-01 00:33:29  Room-3         0       17.3       0.0
# 1     4599621 2023-04-01 00:38:39  Room-3         0       17.4       0.0
# 2     4599638 2023-04-01 00:43:50  Room-3         1       17.1       0.0
# 3     4599656 2023-04-01 00:48:58  Room-3         1       17.1       0.0
# 4     4600896 2023-04-01 07:15:58  Room-3         1       18.0       0.0
# ...       ...                 ...     ...       ...        ...       ...
# 7003  4822392 2023-07-03 18:24:34  Room-3         0       27.6       0.0
# 7004  4822407 2023-07-03 18:29:44  Room-3         0       27.5       0.0
# 7005  4855753 2023-07-26 12:06:31  Room-3         0       26.5      25.9
# 7006  4855764 2023-07-26 12:11:43  Room-3         0       26.6      25.8
# 7007  4855784 2023-07-26 12:19:54  Room-3         0       26.7      25.8
#
#       Room_Hum  Humidity_Avg  Heater_1  Fan_1  Fan_2  Fan_3  Fan_4
# ...

# %% [markdown]
# ## **_1) Solenoid Valve_**

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Iterate through each row in the dataset
for index, row in cold3.iterrows():
    date = row['P_Date'].date()
    solenoid = row['Solenoid']
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold3.loc[index - 1, 'Solenoid']
        if solenoid != prev_solenoid:
            if solenoid == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1

# Print count of solenoid ON and OFF for each date
for date, count in solenoid_on_count.items():
    off_count = solenoid_off_count.get(date, 0)
    print(f"{date}:  ON:   {count},            OFF:  {off_count},          Total: {count + off_count}")


# Convert dictionaries to lists for plotting
dates = list(solenoid_on_count.keys())
on_counts = list(solenoid_on_count.values())
off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
plt.figure(figsize=(15, 5))
plt.bar(dates, on_counts, color='green', label='Solenoid ON')
plt.bar(dates, off_counts, color='yellow', bottom=on_counts, label='Solenoid OFF')
plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Solenoid ON/OFF Count for Each Date')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 2023-04-01:  ON:   2,            OFF:  1,          Total: 3
# 2023-04-02:  ON:   3,            OFF:  3,          Total: 6
# 2023-04-03:  ON:   2,            OFF:  2,          Total: 4
# 2023-04-04:  ON:   3,            OFF:  3,          Total: 6
# 2023-04-05:  ON:   1,            OFF:  2,          Total: 3
# 2023-04-08:  ON:   1,            OFF:  1,          Total: 2
# 2023-04-11:  ON:   1,            OFF:  0,          Total: 1
# 2023-04-19:  ON:   1,            OFF:  0,          Total: 1
# 2023-04-20:  ON:   2,            OFF:  3,          Total: 5
# 2023-04-25:  ON:   1,            OFF:  0,          Total: 1
# 2023-04-26:  ON:   2,            OFF:  2,          Total: 4
# 2023-04-27:  ON:   2,            OFF:  2,          Total: 4
# 2023-04-28:  ON:   1,            OFF:  1,          Total: 2
# 2023-05-04:  ON:   3,            OFF:  3,          Total: 6
# 2023-05-05:  ON:   3,            OFF:  3,          Total: 6
# 2023-05-07:  ON:   1,            OFF:  1,          Total: 2
# ...

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Initialize lists to store room temperature data
room_temp_dates = []
room_temp_values = []

# Iterate through each row in the dataset
for index, row in cold3.iterrows():
    date = row['P_Date'].date()
    solenoid = row['Solenoid']
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold3.loc[index - 1, 'Solenoid']
        if solenoid != prev_solenoid:
            if solenoid == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1
    
    # Store room temperature data
    room_temp_dates.append(date)
    room_temp_values.append(row['Room_Temp'])

# Convert dictionaries to lists for plotting
dates = list(solenoid_on_count.keys())
on_counts = list(solenoid_on_count.values())
off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
fig, ax1 = plt.subplots(figsize=(15, 6))
ax2 = ax1.twinx()

# Plot solenoid ON/OFF counts
ax1.bar(dates, on_counts, color='green', label='Solenoid ON')
ax1.bar(dates, off_counts, color='yellow', bottom=on_counts, label='Solenoid OFF')
ax1.set_xlabel('Date')
ax1.set_ylabel('Count')
ax1.set_title('Solenoid ON/OFF Count and Room Temperature')
ax1.legend(loc='upper left')
ax1.tick_params(axis='x', rotation=45)

# Plot room temperature
ax2.plot(room_temp_dates, room_temp_values, color='red', linestyle='-', label='Room Temp')
ax2.set_ylabel('Room Temperature')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Initialize lists to store room humidity data
room_hum_dates = []
room_hum_values = []

# Iterate through each row in the dataset
for index, row in cold3.iterrows():
    date = row['P_Date'].date()
    solenoid = row['Solenoid']
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold3.loc[index - 1, 'Solenoid']
        if solenoid != prev_solenoid:
            if solenoid == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1
    
    # Store room humidity data
    room_hum_dates.append(date)
    room_hum_values.append(row['Room_Hum'])

# Convert dictionaries to lists for plotting
dates = list(solenoid_on_count.keys())
on_counts = list(solenoid_on_count.values())
off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
fig, ax1 = plt.subplots(figsize=(15, 6))
ax2 = ax1.twinx()

# Plot solenoid ON/OFF counts
ax1.bar(dates, on_counts, color='green', label='Solenoid ON')
ax1.bar(dates, off_counts, color='yellow', bottom=on_counts, label='Solenoid OFF')
ax1.set_xlabel('Date')
ax1.set_ylabel('Count')
ax1.set_title('Solenoid ON/OFF Count and Room Humidity')
ax1.legend(loc='upper left')
ax1.tick_params(axis='x', rotation=45)

# Plot room humidity
ax2.plot(room_hum_dates, room_hum_values, color='blue', linestyle='-', label='Room Hum')
ax2.set_ylabel('Room Humidity')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Initialize lists to store room temperature and humidity data
room_temp_dates = []
room_temp_values = []
room_hum_values = []

# Iterate through each row in the dataset
for index, row in cold3.iterrows():
    date = row['P_Date'].date()
    solenoid = row['Solenoid']
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold3.loc[index - 1, 'Solenoid']
        if solenoid != prev_solenoid:
            if solenoid == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1
    
    # Store room temperature and humidity data
    room_temp_dates.append(date)
    room_temp_values.append(row['Room_Temp'])
    room_hum_values.append(row['Room_Hum'])

# Convert dictionaries to lists for plotting
dates = list(solenoid_on_count.keys())
on_counts = list(solenoid_on_count.values())
off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 8))
ax2 = ax1.twinx()

# Plot solenoid ON/OFF counts
ax1.bar(dates, on_counts, color='green', label='Solenoid ON')
ax1.bar(dates, off_counts, color='yellow', bottom=on_counts, label='Solenoid OFF')
ax1.set_xlabel('Date')
ax1.set_ylabel('Count')
ax1.set_title('Solenoid ON/OFF Count, Room Temperature, and Room Humidity')
ax1.legend(loc='upper left')
ax1.tick_params(axis='x', rotation=45)

# Plot room temperature
ax2.plot(room_temp_dates, room_temp_values, color='red', linestyle='-', label='Room Temp')
ax2.plot(room_temp_dates, room_hum_values, color='blue', linestyle='-', label='Room Humidity')
ax2.set_ylabel('Value')
ax2.set_ylim(0, 100)
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
from datetime import datetime, timedelta

# Initialize dictionaries to track time for each state
solenoid_on_time = {}
solenoid_off_time = {}

# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Iterate through each row in the dataset
for index, row in cold3.iterrows():
    date = row['P_Date'].date()
    solenoid = row['Solenoid']
    timestamp = row['P_Date']
    
    # Initialize time if not present
    if date not in solenoid_on_time:
        solenoid_on_time[date] = timedelta()
    if date not in solenoid_off_time:
        solenoid_off_time[date] = timedelta()
    
    # Initialize count if not present
    if date not in solenoid_on_count:
        solenoid_on_count[date] = 0
    if date not in solenoid_off_count:
        solenoid_off_count[date] = 0
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold3.loc[index - 1, 'Solenoid']
        prev_timestamp = cold3.loc[index - 1, 'P_Date']
        
        if solenoid != prev_solenoid:
            time_diff = timestamp - prev_timestamp
            if solenoid == 1:
                solenoid_on_time[date] += time_diff
                solenoid_on_count[date] += 1
            else:
                solenoid_off_time[date] += time_diff
                solenoid_off_count[date] += 1

# Print count of solenoid ON and OFF for each date
for date, count in solenoid_on_count.items():
    off_count = solenoid_off_count.get(date, 0)
    print(f"{date}:    ON: {count},  {solenoid_on_time[date]},                  OFF: {off_count},  {solenoid_off_time[date]}")
    print (f"               Total Count: {count + off_count}                Total timing: {solenoid_on_time[date] + solenoid_off_time[date]}")


# Print total time ON and OFF for each date
for date, time_on in solenoid_on_time.items():
    time_off = solenoid_off_time[date]
    total_time_on = time_on.total_seconds()
    total_time_off = time_off.total_seconds()
    total_time = total_time_on + total_time_off


# Convert timedelta to seconds for plotting
time_on_seconds = {date: time.total_seconds() for date, time in solenoid_on_time.items()}
time_off_seconds = {date: time.total_seconds() for date, time in solenoid_off_time.items()}

# Plotting
plt.figure(figsize=(15, 6))

plt.plot(list(time_on_seconds.keys()), list(time_on_seconds.values()), label='Time ON', marker='o', color='Green')
plt.plot(list(time_off_seconds.keys()), list(time_off_seconds.values()), label='Time OFF', marker='o', color='yellow')

plt.title('Solenoid ON/OFF Time')
plt.xlabel('Date')
plt.ylabel('Time (seconds)')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()
# Out:
# 2023-04-01:    ON: 2,  0 days 00:10:22,                  OFF: 1,  0 days 00:05:09
#                Total Count: 3                Total timing: 0 days 00:15:31
# 2023-04-02:    ON: 3,  0 days 00:15:29,                  OFF: 3,  0 days 00:15:27
#                Total Count: 6                Total timing: 0 days 00:30:56
# 2023-04-03:    ON: 2,  0 days 00:10:19,                  OFF: 2,  0 days 00:10:18
#                Total Count: 4                Total timing: 0 days 00:20:37
# 2023-04-04:    ON: 3,  0 days 00:15:30,                  OFF: 3,  0 days 00:15:26
#                Total Count: 6                Total timing: 0 days 00:30:56
# 2023-04-05:    ON: 1,  0 days 00:05:09,                  OFF: 2,  0 days 06:32:04
#                Total Count: 3                Total timing: 0 days 06:37:13
# 2023-04-06:    ON: 0,  0:00:00,                  OFF: 0,  0:00:00
#                Total Count: 0                Total timing: 0:00:00
# ...

# %% [markdown]
# ## **_2) Heater_**

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
heater_on_count = {}
heater_off_count = {}

# Iterate through each row in the dataset
for index, row in cold3.iterrows():
    date = row['P_Date'].date()
    heater = row['Heater_1']
    
    # Increment count if heater state changes
    if index > 0:
        prev_heater = cold3.loc[index - 1, 'Heater_1']
        if heater != prev_heater:
            if heater == 1:
                heater_on_count[date] = heater_on_count.get(date, 0) + 1
            else:
                heater_off_count[date] = heater_off_count.get(date, 0) + 1

# Print count of heater ON and OFF for each date
for date, count in heater_on_count.items():
    off_count = heater_off_count.get(date, 0)
    print(f"{date}:  ON:   {count},            OFF:  {off_count},          Total: {count + off_count}")


# Convert dictionaries to lists for plotting
dates = list(heater_on_count.keys())
on_counts = list(heater_on_count.values())
off_counts = [heater_off_count.get(date, 0) for date in dates]

# Plotting
plt.figure(figsize=(15, 5))
plt.bar(dates, on_counts, color='skyblue', label='Heater ON')
plt.bar(dates, off_counts, color='orange', bottom=on_counts, label='Heater OFF')
plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Heater ON/OFF Count for Each Date')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 2023-04-20:  ON:   2,            OFF:  2,          Total: 4
# 2023-05-10:  ON:   1,            OFF:  1,          Total: 2
# 2023-05-13:  ON:   1,            OFF:  1,          Total: 2
# 2023-05-15:  ON:   4,            OFF:  4,          Total: 8
# 2023-05-19:  ON:   1,            OFF:  1,          Total: 2
# 2023-05-20:  ON:   2,            OFF:  2,          Total: 4
# 2023-05-25:  ON:   1,            OFF:  0,          Total: 1
# 2023-05-26:  ON:   2,            OFF:  2,          Total: 4
# 2023-05-27:  ON:   3,            OFF:  3,          Total: 6
# 2023-05-28:  ON:   3,            OFF:  3,          Total: 6
# 2023-05-29:  ON:   1,            OFF:  2,          Total: 3
# 2023-06-06:  ON:   9,            OFF:  8,          Total: 17

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Initialize lists to store room temperature and humidity data
room_temp_dates = []
room_temp_values = []
room_hum_values = []

# Iterate through each row in the dataset
for index, row in cold3.iterrows():
    date = row['P_Date'].date()
    heater = row['Heater_1']
    
    # Increment count if heater state changes
    if index > 0:
        prev_heater = cold3.loc[index - 1, 'Heater_1']
        if heater != prev_heater:
            if heater == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1
    
    # Store room temperature and humidity data
    room_temp_dates.append(date)
    room_temp_values.append(row['Room_Temp'])
    room_hum_values.append(row['Room_Hum'])

# Convert dictionaries to lists for plotting
dates = list(solenoid_on_count.keys())
on_counts = list(solenoid_on_count.values())
off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 8))
ax2 = ax1.twinx()

# Plot heater ON/OFF counts
ax1.bar(dates, on_counts, color='skyblue', label='Heater ON')
ax1.bar(dates, off_counts, color='orange', bottom=on_counts, label='Heater OFF')
ax1.set_xlabel('Date')
ax1.set_ylabel('Count')
ax1.set_title('Heater ON/OFF Count, Room Temperature, and Room Humidity')
ax1.legend(loc='upper left')
ax1.tick_params(axis='x', rotation=45)

# Plot room temperature
ax2.plot(room_temp_dates, room_temp_values, color='red', linestyle='-', label='Room Temp')
ax2.plot(room_temp_dates, room_hum_values, color='blue', linestyle='-', label='Room Humidity')
ax2.set_ylabel('Temperature/Humidity')
ax2.set_ylim(0, 100)
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
from datetime import datetime, timedelta

# Initialize dictionaries to track time for each state
heater_on_time = {}
heater_off_time = {}

# Initialize dictionaries to track count of ON and OFF switches for each date
heater_on_count = {}
heater_off_count = {}

# Iterate through each row in the dataset
for index, row in cold3.iterrows():
    date = row['P_Date'].date()
    heater = row['Heater_1']
    timestamp = row['P_Date']
    
    # Initialize time if not present
    if date not in heater_on_time:
        heater_on_time[date] = timedelta()
    if date not in heater_off_time:
        heater_off_time[date] = timedelta()
    
    # Initialize count if not present
    if date not in heater_on_count:
        heater_on_count[date] = 0
    if date not in heater_off_count:
        heater_off_count[date] = 0
    
    # Increment count if heater state changes
    if index > 0:
        prev_heater = cold3.loc[index - 1, 'Heater_1']
        prev_timestamp = cold3.loc[index - 1, 'P_Date']
        
        if heater != prev_heater:
            time_diff = timestamp - prev_timestamp
            if heater == 1:
                heater_on_time[date] += time_diff
                heater_on_count[date] += 1
            else:
                heater_off_time[date] += time_diff
                heater_off_count[date] += 1

# Print count of heater ON and OFF for each date
for date, count in heater_on_count.items():
    off_count = heater_off_count.get(date, 0)
    print(f"{date}:    ON: {count},  {heater_on_time[date]},                   OFF: {off_count},  {heater_off_time[date]}                Total Count: {count + off_count}                Total timing: {heater_on_time[date] + heater_off_time[date]}")

# Print total time ON and OFF for each date
for date, time_on in heater_on_time.items():
    time_off = heater_off_time[date]
    total_time_on = time_on.total_seconds()
    total_time_off = time_off.total_seconds()
    total_time = total_time_on + total_time_off
# Out:
# 2023-04-01:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-02:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-03:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-04:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-05:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-06:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-07:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# ...

# %%
from datetime import datetime, timedelta

# Initialize dictionaries to track time for each state
heater_on_time = {}
heater_off_time = {}

# Initialize dictionaries to track count of ON and OFF switches for each date
heater_on_count = {}
heater_off_count = {}

# Iterate through each row in the dataset
for index, row in cold3.iterrows():
    date = row['P_Date'].date()
    heater = row['Heater_1']
    timestamp = row['P_Date']
    
    # Initialize time if not present
    if date not in heater_on_time:
        heater_on_time[date] = timedelta()
    if date not in heater_off_time:
        heater_off_time[date] = timedelta()
    
    # Initialize count if not present
    if date not in heater_on_count:
        heater_on_count[date] = 0
    if date not in heater_off_count:
        heater_off_count[date] = 0
    
    # Increment count if heater state changes
    if index > 0:
        prev_heater = cold3.loc[index - 1, 'Heater_1']
        prev_timestamp = cold3.loc[index - 1, 'P_Date']
        
        if heater != prev_heater:
            time_diff = timestamp - prev_timestamp
            if heater == 1:
                heater_on_time[date] += time_diff
                heater_on_count[date] += 1
            else:
                heater_off_time[date] += time_diff
                heater_off_count[date] += 1

# Print count of heater ON and OFF for each date
for date, count in heater_on_count.items():
    off_count = heater_off_count.get(date, 0)
    if count != 0 or off_count != 0:
        print(f"{date}:    ON: {count},  {heater_on_time[date]},                   OFF: {off_count},  {heater_off_time[date]}                Total Count: {count + off_count}                Total timing: {heater_on_time[date] + heater_off_time[date]}")

# Print total time ON and OFF for each date
for date, time_on in heater_on_time.items():
    time_off = heater_off_time[date]
    total_time_on = time_on.total_seconds()
    total_time_off = time_off.total_seconds()
    total_time = total_time_on + total_time_off


# Extract dates and total time ON and OFF from dictionaries
dates = list(heater_on_time.keys())
total_time_on = [heater_on_time[date].total_seconds() / 3600 for date in dates]  # Convert to hours
total_time_off = [heater_off_time[date].total_seconds() / 3600 for date in dates]  # Convert to hours

# Plotting
plt.figure(figsize=(25, 6))
plt.plot(dates, total_time_on, marker='o', linestyle='-', label='Total Time ON')
plt.plot(dates, total_time_off, marker='o', linestyle='-', label='Total Time OFF')
plt.title('Total Heater ON and OFF Time Over Time')
plt.xlabel('Date')
plt.ylabel('Total Time (hours)')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 2023-04-20:    ON: 2,  0 days 00:10:21,                   OFF: 2,  0 days 00:50:28                Total Count: 4                Total timing: 0 days 01:00:49
# 2023-05-10:    ON: 1,  0 days 00:05:09,                   OFF: 1,  0 days 00:05:10                Total Count: 2                Total timing: 0 days 00:10:19
# 2023-05-13:    ON: 1,  0 days 04:40:52,                   OFF: 1,  0 days 00:31:17                Total Count: 2                Total timing: 0 days 05:12:09
# 2023-05-15:    ON: 4,  0 days 00:30:53,                   OFF: 4,  0 days 00:25:57                Total Count: 8                Total timing: 0 days 00:56:50
# 2023-05-19:    ON: 1,  0 days 12:48:23,                   OFF: 1,  0 days 00:05:09                Total Count: 2                Total timing: 0 days 12:53:32
# 2023-05-20:    ON: 2,  0 days 00:10:10,                   OFF: 2,  0 days 00:10:21                Total Count: 4                Total timing: 0 days 00:20:31
# ...

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
heater_on_count = {}
heater_off_count = {}
solenoid_on_count = {}
solenoid_off_count = {}

# Iterate through each row in the dataset
for index, row in cold3.iterrows():
    date = row['P_Date'].date()
    heater = row['Heater_1']
    solenoid = row['Solenoid']
    
    # Increment count if heater state changes
    if index > 0:
        prev_heater = cold3.loc[index - 1, 'Heater_1']
        if heater != prev_heater:
            if heater == 1:
                heater_on_count[date] = heater_on_count.get(date, 0) + 1
            else:
                heater_off_count[date] = heater_off_count.get(date, 0) + 1
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold3.loc[index - 1, 'Solenoid']
        if solenoid != prev_solenoid:
            if solenoid == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1

# Get common dates for both heater and solenoid data
common_dates = set(heater_on_count.keys()).intersection(solenoid_on_count.keys())

# Convert dictionaries to lists for plotting
dates = list(common_dates)
index = np.arange(len(dates))

heater_on_counts = [heater_on_count[date] for date in dates]
heater_off_counts = [heater_off_count.get(date, 0) for date in dates]

solenoid_on_counts = [solenoid_on_count[date] for date in dates]
solenoid_off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
bar_width = 0.35

plt.figure(figsize=(15, 5))

plt.bar(index, heater_on_counts, bar_width, color='skyblue', label='Heater ON')
plt.bar(index + bar_width, solenoid_on_counts, bar_width, color='green', label='Solenoid ON')

plt.bar(index, heater_off_counts, bar_width, color='orange', label='Heater OFF', bottom=heater_on_counts)
plt.bar(index + bar_width, solenoid_off_counts, bar_width, color='yellow', label='Solenoid OFF', bottom=solenoid_on_counts)

plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Heater and Solenoid ON/OFF Count for Each Date')
plt.xticks(index + bar_width / 2, dates, rotation=45)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **_3) Fans 1, 2, 3, 4_**

# %%
# Initialize dictionaries to track count of ON and OFF switches for each fan on each date
fan_on_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}
fan_off_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}

# Get unique dates from the dataset
unique_dates = set(cold3['P_Date'].dt.date)

# Iterate through each unique date
for date in unique_dates:
    print(f"Date: {date}")
    
    # Iterate through each fan
    for fan_num in range(1, 5):
        fan_name = f'Fan_{fan_num}'
        fan_state = cold3.loc[cold3['P_Date'].dt.date == date, fan_name].values
        
        # Get previous state of the fan
        prev_fan_state = cold3.loc[cold3['P_Date'].dt.date == date, fan_name].shift().values
        prev_fan_state[0] = 0  
        
        # Count ON and OFF switches for the current date
        on_count = sum((fan_state == 1) & (prev_fan_state == 0))
        off_count = sum((fan_state == 0) & (prev_fan_state == 1))
        
        # Update counts in the dictionaries
        fan_on_count[fan_name][date] = on_count
        fan_off_count[fan_name][date] = off_count
        
        # Display fan status for the current date
        total_count = on_count + off_count
        print(f"    {fan_name}: ON: {on_count}, OFF: {off_count}, Total: {total_count}")

    print()
# Out:
# Date: 2023-04-08
#     Fan_1: ON: 1, OFF: 1, Total: 2
#     Fan_2: ON: 1, OFF: 1, Total: 2
#     Fan_3: ON: 1, OFF: 1, Total: 2
#     Fan_4: ON: 1, OFF: 1, Total: 2
#
# Date: 2023-05-06
#     Fan_1: ON: 1, OFF: 0, Total: 1
#     Fan_2: ON: 1, OFF: 0, Total: 1
#     Fan_3: ON: 1, OFF: 0, Total: 1
#     Fan_4: ON: 1, OFF: 0, Total: 1
#
# Date: 2023-04-05
#     Fan_1: ON: 2, OFF: 2, Total: 4
#     Fan_2: ON: 2, OFF: 2, Total: 4
#     Fan_3: ON: 2, OFF: 2, Total: 4
#     Fan_4: ON: 2, OFF: 2, Total: 4
#
# Date: 2023-05-13
#     Fan_1: ON: 2, OFF: 1, Total: 3
#     Fan_2: ON: 2, OFF: 1, Total: 3
#     Fan_3: ON: 2, OFF: 1, Total: 3
#     Fan_4: ON: 2, OFF: 1, Total: 3
#
# Date: 2023-05-12
#     Fan_1: ON: 4, OFF: 3, Total: 7
#     Fan_2: ON: 4, OFF: 3, Total: 7
#     Fan_3: ON: 4, OFF: 3, Total: 7
#     Fan_4: ON: 4, OFF: 3, Total: 7
#
# Date: 2023-05-31
#     Fan_1: ON: 1, OFF: 0, Total: 1
#     Fan_2: ON: 1, OFF: 0, Total: 1
#     Fan_3: ON: 1, OFF: 0, Total: 1
# ...

# %%
# Initialize dictionaries to track count of ON and OFF switches for each fan on each date
fan_on_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}
fan_off_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}

# Get unique dates from the dataset
unique_dates = sorted(set(cold3['P_Date'].dt.date))

# Iterate through each unique date
for date in unique_dates:
    # Iterate through each fan
    for fan_num in range(1, 5):
        fan_name = f'Fan_{fan_num}'
        fan_state = cold3.loc[cold3['P_Date'].dt.date == date, fan_name].values
        
        # Get previous state of the fan
        prev_fan_state = cold3.loc[cold3['P_Date'].dt.date == date, fan_name].shift().values
        prev_fan_state[0] = 0  # For the first row, set previous state to 0
        
        # Count ON and OFF switches for the current date
        on_count = sum((fan_state == 1) & (prev_fan_state == 0))
        off_count = sum((fan_state == 0) & (prev_fan_state == 1))
        
        # Update counts in the dictionaries
        fan_on_count[fan_name][date] = on_count
        fan_off_count[fan_name][date] = off_count

# Plotting the grouped bar plot
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
axes = axes.ravel()

bar_width = 0.35
index = range(len(unique_dates))

for i, fan_name in enumerate(fan_on_count.keys()):
    dates = list(unique_dates)
    on_counts = [fan_on_count[fan_name][date] for date in dates]
    off_counts = [fan_off_count[fan_name][date] for date in dates]

    axes[i].bar(index, on_counts, bar_width, label='ON', color='grey', align='center')
    axes[i].bar(index, off_counts, bar_width, label='OFF', color='black', align='center', bottom=on_counts)
    
    axes[i].set_xlabel('Date')
    axes[i].set_ylabel('Count')
    axes[i].set_title(fan_name)
    axes[i].legend()

fig.tight_layout()
plt.show()

# %%
# Initialize dictionaries to track count of ON and OFF switches for each fan on each date
fan_on_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}
fan_off_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}

# Get unique dates from the dataset
unique_dates = sorted(set(cold3['P_Date'].dt.date))

# Iterate through each unique date
for date in unique_dates:
    # Iterate through each fan
    for fan_num in range(1, 5):
        fan_name = f'Fan_{fan_num}'
        fan_state = cold3.loc[cold3['P_Date'].dt.date == date, fan_name].values
        
        # Get previous state of the fan
        prev_fan_state = cold3.loc[cold3['P_Date'].dt.date == date, fan_name].shift().values
        prev_fan_state[0] = 0  
        
        # Count ON and OFF switches for the current date
        on_count = sum((fan_state == 1) & (prev_fan_state == 0))
        off_count = sum((fan_state == 0) & (prev_fan_state == 1))
        
        # Update counts in the dictionaries
        fan_on_count[fan_name][date] = on_count
        fan_off_count[fan_name][date] = off_count

# Plotting the graph
fig, axes = plt.subplots(2, 2, figsize=(25, 8))
axes = axes.ravel()

for i, fan_name in enumerate(fan_on_count.keys()):
    dates = list(unique_dates)
    on_counts = [fan_on_count[fan_name][date] for date in dates]
    off_counts = [fan_off_count[fan_name][date] for date in dates]
    # total_counts = [on + off for on, off in zip(on_counts, off_counts)]

    axes[i].plot(dates, on_counts, label='ON', color= 'grey')
    axes[i].plot(dates, off_counts, label='OFF', color= 'black')
    # axes[i].plot(dates, total_counts, label='Total')
    axes[i].set_title(fan_name)
    axes[i].legend()

# Set common labels
fig.text(0.5, 0.04, 'Date', ha='center', va='center')
fig.text(0.06, 0.5, 'Count', ha='center', va='center', rotation='vertical')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **<mark>ROOM 4</mark>**

# %%
cold4 = cold[['P_ID', 'P_Date', 'Room', 'Solenoid', 'Room_Temp', 'Temp_Avg', 'Room_Hum', 'Humidity_Avg', 'Heater_1', 'Fan_1', 'Fan_2', 'Fan_3', 'Fan_4']]
cold4 = cold4[cold4["Room"]=="Room-4"].reset_index(drop=True)
cold4
# Out:
#          P_ID              P_Date    Room  Solenoid  Room_Temp  Temp_Avg  \
# 0     4599499 2023-04-01 00:02:05  Room-4         0       27.7       0.0
# 1     4599516 2023-04-01 00:07:15  Room-4         0       27.6       0.0
# 2     4599531 2023-04-01 00:12:24  Room-4         0       27.6       0.0
# 3     4599549 2023-04-01 00:17:34  Room-4         0       27.5       0.0
# 4     4599564 2023-04-01 00:22:44  Room-4         0       27.6       0.0
# ...       ...                 ...     ...       ...        ...       ...
# 5459  4822330 2023-07-03 18:05:21  Room-4         0       27.2       0.0
# 5460  4822345 2023-07-03 18:10:29  Room-4         0       27.1       0.0
# 5461  4822362 2023-07-03 18:15:40  Room-4         0       27.1       0.0
# 5462  4822379 2023-07-03 18:20:49  Room-4         0       27.1       0.0
# 5463  4822395 2023-07-03 18:25:59  Room-4         0       27.1       0.0
#
#       Room_Hum  Humidity_Avg  Heater_1  Fan_1  Fan_2  Fan_3  Fan_4
# ...

# %% [markdown]
# ## **_1) Solenoid Valve_**

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Iterate through each row in the dataset
for index, row in cold4.iterrows():
    date = row['P_Date'].date()
    solenoid = row['Solenoid']
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold4.loc[index - 1, 'Solenoid']
        if solenoid != prev_solenoid:
            if solenoid == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1

# Print count of solenoid ON and OFF for each date
for date, count in solenoid_on_count.items():
    off_count = solenoid_off_count.get(date, 0)
    print(f"{date}:  ON:   {count},            OFF:  {off_count},          Total: {count + off_count}")


# Convert dictionaries to lists for plotting
dates = list(solenoid_on_count.keys())
on_counts = list(solenoid_on_count.values())
off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
plt.figure(figsize=(15, 5))
plt.bar(dates, on_counts, color='green', label='Solenoid ON')
plt.bar(dates, off_counts, color='yellow', bottom=on_counts, label='Solenoid OFF')
plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Solenoid ON/OFF Count for Each Date')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 2023-04-01:  ON:   3,            OFF:  2,          Total: 5
# 2023-04-02:  ON:   3,            OFF:  3,          Total: 6
# 2023-04-03:  ON:   2,            OFF:  2,          Total: 4
# 2023-04-04:  ON:   3,            OFF:  3,          Total: 6
# 2023-04-05:  ON:   1,            OFF:  2,          Total: 3
# 2023-04-12:  ON:   1,            OFF:  0,          Total: 1
# 2023-04-19:  ON:   1,            OFF:  0,          Total: 1
# 2023-04-20:  ON:   1,            OFF:  2,          Total: 3
# 2023-04-25:  ON:   2,            OFF:  1,          Total: 3
# 2023-04-26:  ON:   13,            OFF:  13,          Total: 26
# 2023-04-27:  ON:   2,            OFF:  2,          Total: 4
# 2023-04-28:  ON:   1,            OFF:  1,          Total: 2
# 2023-04-29:  ON:   1,            OFF:  1,          Total: 2
# 2023-05-04:  ON:   3,            OFF:  3,          Total: 6
# 2023-05-05:  ON:   3,            OFF:  3,          Total: 6
# 2023-05-07:  ON:   1,            OFF:  1,          Total: 2
# ...

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Initialize lists to store room temperature data
room_temp_dates = []
room_temp_values = []

# Iterate through each row in the dataset
for index, row in cold4.iterrows():
    date = row['P_Date'].date()
    solenoid = row['Solenoid']
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold4.loc[index - 1, 'Solenoid']
        if solenoid != prev_solenoid:
            if solenoid == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1
    
    # Store room temperature data
    room_temp_dates.append(date)
    room_temp_values.append(row['Room_Temp'])

# Convert dictionaries to lists for plotting
dates = list(solenoid_on_count.keys())
on_counts = list(solenoid_on_count.values())
off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
fig, ax1 = plt.subplots(figsize=(15, 5))
ax2 = ax1.twinx()

# Plot solenoid ON/OFF counts
ax1.bar(dates, on_counts, color='green', label='Solenoid ON')
ax1.bar(dates, off_counts, color='yellow', bottom=on_counts, label='Solenoid OFF')
ax1.set_xlabel('Date')
ax1.set_ylabel('Count')
ax1.set_title('Solenoid ON/OFF Count and Room Temperature')
ax1.legend(loc='upper left')
ax1.tick_params(axis='x', rotation=45)

# Plot room temperature
ax2.plot(room_temp_dates, room_temp_values, color='red', linestyle='-', label='Room Temp')
ax2.set_ylabel('Room Temperature')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Initialize lists to store room humidity data
room_hum_dates = []
room_hum_values = []

# Iterate through each row in the dataset
for index, row in cold4.iterrows():
    date = row['P_Date'].date()
    solenoid = row['Solenoid']
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold4.loc[index - 1, 'Solenoid']
        if solenoid != prev_solenoid:
            if solenoid == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1
    
    # Store room humidity data
    room_hum_dates.append(date)
    room_hum_values.append(row['Room_Hum'])

# Convert dictionaries to lists for plotting
dates = list(solenoid_on_count.keys())
on_counts = list(solenoid_on_count.values())
off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
fig, ax1 = plt.subplots(figsize=(15, 6))
ax2 = ax1.twinx()

# Plot solenoid ON/OFF counts
ax1.bar(dates, on_counts, color='green', label='Solenoid ON')
ax1.bar(dates, off_counts, color='yellow', bottom=on_counts, label='Solenoid OFF')
ax1.set_xlabel('Date')
ax1.set_ylabel('Count')
ax1.set_title('Solenoid ON/OFF Count and Room Humidity')
ax1.legend(loc='upper left')
ax1.tick_params(axis='x', rotation=45)

# Plot room humidity
ax2.plot(room_hum_dates, room_hum_values, color='blue', linestyle='-', label='Room Hum')
ax2.set_ylabel('Room Humidity')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Initialize lists to store room temperature and humidity data
room_temp_dates = []
room_temp_values = []
room_hum_values = []

# Iterate through each row in the dataset
for index, row in cold4.iterrows():
    date = row['P_Date'].date()
    solenoid = row['Solenoid']
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold4.loc[index - 1, 'Solenoid']
        if solenoid != prev_solenoid:
            if solenoid == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1
    
    # Store room temperature and humidity data
    room_temp_dates.append(date)
    room_temp_values.append(row['Room_Temp'])
    room_hum_values.append(row['Room_Hum'])

# Convert dictionaries to lists for plotting
dates = list(solenoid_on_count.keys())
on_counts = list(solenoid_on_count.values())
off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 8))
ax2 = ax1.twinx()

# Plot solenoid ON/OFF counts
ax1.bar(dates, on_counts, color='green', label='Solenoid ON')
ax1.bar(dates, off_counts, color='yellow', bottom=on_counts, label='Solenoid OFF')
ax1.set_xlabel('Date')
ax1.set_ylabel('Count')
ax1.set_title('Solenoid ON/OFF Count, Room Temperature, and Room Humidity')
ax1.legend(loc='upper left')
ax1.tick_params(axis='x', rotation=45)

# Plot room temperature
ax2.plot(room_temp_dates, room_temp_values, color='red', linestyle='-', label='Room Temp')
ax2.plot(room_temp_dates, room_hum_values, color='blue', linestyle='-', label='Room Humidity')
ax2.set_ylabel('Value')
ax2.set_ylim(0, 100)
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
from datetime import datetime, timedelta

# Initialize dictionaries to track time for each state
solenoid_on_time = {}
solenoid_off_time = {}

# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Iterate through each row in the dataset
for index, row in cold4.iterrows():
    date = row['P_Date'].date()
    solenoid = row['Solenoid']
    timestamp = row['P_Date']
    
    # Initialize time if not present
    if date not in solenoid_on_time:
        solenoid_on_time[date] = timedelta()
    if date not in solenoid_off_time:
        solenoid_off_time[date] = timedelta()
    
    # Initialize count if not present
    if date not in solenoid_on_count:
        solenoid_on_count[date] = 0
    if date not in solenoid_off_count:
        solenoid_off_count[date] = 0
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold4.loc[index - 1, 'Solenoid']
        prev_timestamp = cold4.loc[index - 1, 'P_Date']
        
        if solenoid != prev_solenoid:
            time_diff = timestamp - prev_timestamp
            if solenoid == 1:
                solenoid_on_time[date] += time_diff
                solenoid_on_count[date] += 1
            else:
                solenoid_off_time[date] += time_diff
                solenoid_off_count[date] += 1

# Print count of solenoid ON and OFF for each date
for date, count in solenoid_on_count.items():
    off_count = solenoid_off_count.get(date, 0)
    print(f"{date}:    ON: {count},  {solenoid_on_time[date]},                  OFF: {off_count},  {solenoid_off_time[date]}")
    print (f"               Total Count: {count + off_count}                Total timing: {solenoid_on_time[date] + solenoid_off_time[date]}")

# Print total time ON and OFF for each date
for date, time_on in solenoid_on_time.items():
    time_off = solenoid_off_time[date]
    total_time_on = time_on.total_seconds()
    total_time_off = time_off.total_seconds()
    total_time = total_time_on + total_time_off


# Convert timedelta to seconds for plotting
time_on_seconds = {date: time.total_seconds() for date, time in solenoid_on_time.items()}
time_off_seconds = {date: time.total_seconds() for date, time in solenoid_off_time.items()}

# Plotting
plt.figure(figsize=(15, 6))

plt.plot(list(time_on_seconds.keys()), list(time_on_seconds.values()), label='Time ON', marker='o', color='Green')
plt.plot(list(time_off_seconds.keys()), list(time_off_seconds.values()), label='Time OFF', marker='o', color='yellow')

plt.title('Solenoid ON/OFF Time')
plt.xlabel('Date')
plt.ylabel('Time (seconds)')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()
# Out:
# 2023-04-01:    ON: 3,  0 days 00:15:30,                  OFF: 2,  0 days 00:10:19
#                Total Count: 5                Total timing: 0 days 00:25:49
# 2023-04-02:    ON: 3,  0 days 00:15:29,                  OFF: 3,  0 days 00:15:30
#                Total Count: 6                Total timing: 0 days 00:30:59
# 2023-04-03:    ON: 2,  0 days 00:20:37,                  OFF: 2,  0 days 00:10:19
#                Total Count: 4                Total timing: 0 days 00:30:56
# 2023-04-04:    ON: 3,  0 days 00:15:29,                  OFF: 3,  0 days 00:15:27
#                Total Count: 6                Total timing: 0 days 00:30:56
# 2023-04-05:    ON: 1,  0 days 00:05:10,                  OFF: 2,  0 days 06:32:19
#                Total Count: 3                Total timing: 0 days 06:37:29
# 2023-04-06:    ON: 0,  0:00:00,                  OFF: 0,  0:00:00
#                Total Count: 0                Total timing: 0:00:00
# ...

# %% [markdown]
# ## **_2) Heater_**

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
heater_on_count = {}
heater_off_count = {}

# Iterate through each row in the dataset
for index, row in cold4.iterrows():
    date = row['P_Date'].date()
    heater = row['Heater_1']
    
    # Increment count if heater state changes
    if index > 0:
        prev_heater = cold4.loc[index - 1, 'Heater_1']
        if heater != prev_heater:
            if heater == 1:
                heater_on_count[date] = heater_on_count.get(date, 0) + 1
            else:
                heater_off_count[date] = heater_off_count.get(date, 0) + 1

# Print count of heater ON and OFF for each date
for date, count in heater_on_count.items():
    off_count = heater_off_count.get(date, 0)
    print(f"{date}:  ON:   {count},            OFF:  {off_count},          Total: {count + off_count}")

# Convert dictionaries to lists for plotting
dates = list(heater_on_count.keys())
on_counts = list(heater_on_count.values())
off_counts = [heater_off_count.get(date, 0) for date in dates]

# Plotting
plt.figure(figsize=(15, 5))
plt.bar(dates, on_counts, color='skyblue', label='Heater ON')
plt.bar(dates, off_counts, color='orange', bottom=on_counts, label='Heater OFF')
plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Heater ON/OFF Count for Each Date')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 2023-04-04:  ON:   2,            OFF:  2,          Total: 4
# 2023-04-05:  ON:   1,            OFF:  1,          Total: 2
# 2023-04-12:  ON:   1,            OFF:  0,          Total: 1
# 2023-04-19:  ON:   1,            OFF:  0,          Total: 1
# 2023-05-10:  ON:   1,            OFF:  1,          Total: 2
# 2023-05-11:  ON:   2,            OFF:  2,          Total: 4
# 2023-05-12:  ON:   2,            OFF:  1,          Total: 3
# 2023-05-13:  ON:   1,            OFF:  1,          Total: 2
# 2023-05-15:  ON:   3,            OFF:  4,          Total: 7
# 2023-05-16:  ON:   2,            OFF:  2,          Total: 4
# 2023-05-17:  ON:   1,            OFF:  0,          Total: 1
# 2023-05-20:  ON:   3,            OFF:  3,          Total: 6
# 2023-05-21:  ON:   2,            OFF:  2,          Total: 4
# 2023-05-29:  ON:   1,            OFF:  2,          Total: 3
# 2023-05-30:  ON:   1,            OFF:  1,          Total: 2
# 2023-06-06:  ON:   1,            OFF:  1,          Total: 2
# ...

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
solenoid_on_count = {}
solenoid_off_count = {}

# Initialize lists to store room temperature and humidity data
room_temp_dates = []
room_temp_values = []
room_hum_values = []

# Iterate through each row in the dataset
for index, row in cold4.iterrows():
    date = row['P_Date'].date()
    heater = row['Heater_1']
    
    # Increment count if heater state changes
    if index > 0:
        prev_heater = cold4.loc[index - 1, 'Heater_1']
        if heater != prev_heater:
            if heater == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1
    
    # Store room temperature and humidity data
    room_temp_dates.append(date)
    room_temp_values.append(row['Room_Temp'])
    room_hum_values.append(row['Room_Hum'])

# Convert dictionaries to lists for plotting
dates = list(solenoid_on_count.keys())
on_counts = list(solenoid_on_count.values())
off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 8))
ax2 = ax1.twinx()

# Plot heater ON/OFF counts
ax1.bar(dates, on_counts, color='skyblue', label='Heater ON')
ax1.bar(dates, off_counts, color='orange', bottom=on_counts, label='Heater OFF')
ax1.set_xlabel('Date')
ax1.set_ylabel('Count')
ax1.set_title('Heater ON/OFF Count, Room Temperature, and Room Humidity')
ax1.legend(loc='upper left')
ax1.tick_params(axis='x', rotation=45)

# Plot room temperature
ax2.plot(room_temp_dates, room_temp_values, color='red', linestyle='-', label='Room Temp')
ax2.plot(room_temp_dates, room_hum_values, color='blue', linestyle='-', label='Room Humidity')
ax2.set_ylabel('Temperature/Humidity')
ax2.set_ylim(0, 100)
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
from datetime import datetime, timedelta

# Initialize dictionaries to track time for each state
heater_on_time = {}
heater_off_time = {}

# Initialize dictionaries to track count of ON and OFF switches for each date
heater_on_count = {}
heater_off_count = {}

# Iterate through each row in the dataset
for index, row in cold4.iterrows():
    date = row['P_Date'].date()
    heater = row['Heater_1']
    timestamp = row['P_Date']
    
    # Initialize time if not present
    if date not in heater_on_time:
        heater_on_time[date] = timedelta()
    if date not in heater_off_time:
        heater_off_time[date] = timedelta()
    
    # Initialize count if not present
    if date not in heater_on_count:
        heater_on_count[date] = 0
    if date not in heater_off_count:
        heater_off_count[date] = 0
    
    # Increment count if heater state changes
    if index > 0:
        prev_heater = cold4.loc[index - 1, 'Heater_1']
        prev_timestamp = cold4.loc[index - 1, 'P_Date']
        
        if heater != prev_heater:
            time_diff = timestamp - prev_timestamp
            if heater == 1:
                heater_on_time[date] += time_diff
                heater_on_count[date] += 1
            else:
                heater_off_time[date] += time_diff
                heater_off_count[date] += 1

# Print count of heater ON and OFF for each date
for date, count in heater_on_count.items():
    off_count = heater_off_count.get(date, 0)
    print(f"{date}:    ON: {count},  {heater_on_time[date]},                   OFF: {off_count},  {heater_off_time[date]}                Total Count: {count + off_count}                Total timing: {heater_on_time[date] + heater_off_time[date]}")

# Print total time ON and OFF for each date
for date, time_on in heater_on_time.items():
    time_off = heater_off_time[date]
    total_time_on = time_on.total_seconds()
    total_time_off = time_off.total_seconds()
    total_time = total_time_on + total_time_off
# Out:
# 2023-04-01:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-02:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-03:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-04:    ON: 2,  0 days 00:10:24,                   OFF: 2,  0 days 00:10:18                Total Count: 4                Total timing: 0 days 00:20:42
# 2023-04-05:    ON: 1,  0 days 00:05:09,                   OFF: 1,  0 days 06:27:09                Total Count: 2                Total timing: 0 days 06:32:18
# 2023-04-06:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# 2023-04-07:    ON: 0,  0:00:00,                   OFF: 0,  0:00:00                Total Count: 0                Total timing: 0:00:00
# ...

# %%
from datetime import datetime, timedelta

# Initialize dictionaries to track time for each state
heater_on_time = {}
heater_off_time = {}

# Initialize dictionaries to track count of ON and OFF switches for each date
heater_on_count = {}
heater_off_count = {}

# Iterate through each row in the dataset
for index, row in cold4.iterrows():
    date = row['P_Date'].date()
    heater = row['Heater_1']
    timestamp = row['P_Date']
    
    # Initialize time if not present
    if date not in heater_on_time:
        heater_on_time[date] = timedelta()
    if date not in heater_off_time:
        heater_off_time[date] = timedelta()
    
    # Initialize count if not present
    if date not in heater_on_count:
        heater_on_count[date] = 0
    if date not in heater_off_count:
        heater_off_count[date] = 0
    
    # Increment count if heater state changes
    if index > 0:
        prev_heater = cold4.loc[index - 1, 'Heater_1']
        prev_timestamp = cold4.loc[index - 1, 'P_Date']
        
        if heater != prev_heater:
            time_diff = timestamp - prev_timestamp
            if heater == 1:
                heater_on_time[date] += time_diff
                heater_on_count[date] += 1
            else:
                heater_off_time[date] += time_diff
                heater_off_count[date] += 1

# Print count of heater ON and OFF for each date
for date, count in heater_on_count.items():
    off_count = heater_off_count.get(date, 0)
    if count != 0 or off_count != 0:
        print(f"{date}:    ON: {count},  {heater_on_time[date]},                   OFF: {off_count},  {heater_off_time[date]}                Total Count: {count + off_count}                Total timing: {heater_on_time[date] + heater_off_time[date]}")

# Print total time ON and OFF for each date
for date, time_on in heater_on_time.items():
    time_off = heater_off_time[date]
    total_time_on = time_on.total_seconds()
    total_time_off = time_off.total_seconds()
    total_time = total_time_on + total_time_off


# Extract dates and total time ON and OFF from dictionaries
dates = list(heater_on_time.keys())
total_time_on = [heater_on_time[date].total_seconds() / 3600 for date in dates]  # Convert to hours
total_time_off = [heater_off_time[date].total_seconds() / 3600 for date in dates]  # Convert to hours

# Plotting
plt.figure(figsize=(25, 6))
plt.plot(dates, total_time_on, marker='o', linestyle='-', label='Total Time ON')
plt.plot(dates, total_time_off, marker='o', linestyle='-', label='Total Time OFF')
plt.title('Total Heater ON and OFF Time Over Time')
plt.xlabel('Date')
plt.ylabel('Total Time (hours)')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 2023-04-04:    ON: 2,  0 days 00:10:24,                   OFF: 2,  0 days 00:10:18                Total Count: 4                Total timing: 0 days 00:20:42
# 2023-04-05:    ON: 1,  0 days 00:05:09,                   OFF: 1,  0 days 06:27:09                Total Count: 2                Total timing: 0 days 06:32:18
# 2023-04-12:    ON: 1,  0 days 00:05:09,                   OFF: 0,  0:00:00                Total Count: 1                Total timing: 0 days 00:05:09
# 2023-04-13:    ON: 0,  0:00:00,                   OFF: 1,  0 days 22:49:52                Total Count: 1                Total timing: 0 days 22:49:52
# 2023-04-19:    ON: 1,  5 days 20:35:30,                   OFF: 0,  0:00:00                Total Count: 1                Total timing: 5 days 20:35:30
# 2023-04-20:    ON: 0,  0:00:00,                   OFF: 1,  0 days 00:15:28                Total Count: 1                Total timing: 0 days 00:15:28
# ...

# %%
# Initialize dictionaries to track count of ON and OFF switches for each date
heater_on_count = {}
heater_off_count = {}
solenoid_on_count = {}
solenoid_off_count = {}

# Iterate through each row in the dataset
for index, row in cold4.iterrows():
    date = row['P_Date'].date()
    heater = row['Heater_1']
    solenoid = row['Solenoid']
    
    # Increment count if heater state changes
    if index > 0:
        prev_heater = cold4.loc[index - 1, 'Heater_1']
        if heater != prev_heater:
            if heater == 1:
                heater_on_count[date] = heater_on_count.get(date, 0) + 1
            else:
                heater_off_count[date] = heater_off_count.get(date, 0) + 1
    
    # Increment count if solenoid state changes
    if index > 0:
        prev_solenoid = cold4.loc[index - 1, 'Solenoid']
        if solenoid != prev_solenoid:
            if solenoid == 1:
                solenoid_on_count[date] = solenoid_on_count.get(date, 0) + 1
            else:
                solenoid_off_count[date] = solenoid_off_count.get(date, 0) + 1

# Get common dates for both heater and solenoid data
common_dates = set(heater_on_count.keys()).intersection(solenoid_on_count.keys())

# Convert dictionaries to lists for plotting
dates = list(common_dates)
index = np.arange(len(dates))

heater_on_counts = [heater_on_count[date] for date in dates]
heater_off_counts = [heater_off_count.get(date, 0) for date in dates]

solenoid_on_counts = [solenoid_on_count[date] for date in dates]
solenoid_off_counts = [solenoid_off_count.get(date, 0) for date in dates]

# Plotting
bar_width = 0.35

plt.figure(figsize=(15, 5))

plt.bar(index, heater_on_counts, bar_width, color='skyblue', label='Heater ON')
plt.bar(index + bar_width, solenoid_on_counts, bar_width, color='green', label='Solenoid ON')

plt.bar(index, heater_off_counts, bar_width, color='orange', label='Heater OFF', bottom=heater_on_counts)
plt.bar(index + bar_width, solenoid_off_counts, bar_width, color='yellow', label='Solenoid OFF', bottom=solenoid_on_counts)

plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Heater and Solenoid ON/OFF Count for Each Date')
plt.xticks(index + bar_width / 2, dates, rotation=45)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **_3) Fans 1, 2, 3, 4_**

# %%
# Initialize dictionaries to track count of ON and OFF switches for each fan on each date
fan_on_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}
fan_off_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}

# Get unique dates from the dataset
unique_dates = set(cold4['P_Date'].dt.date)

# Iterate through each unique date
for date in unique_dates:
    print(f"Date: {date}")
    
    # Iterate through each fan
    for fan_num in range(1, 5):
        fan_name = f'Fan_{fan_num}'
        fan_state = cold4.loc[cold4['P_Date'].dt.date == date, fan_name].values
        
        # Get previous state of the fan
        prev_fan_state = cold4.loc[cold4['P_Date'].dt.date == date, fan_name].shift().values
        prev_fan_state[0] = 0  
        
        # Count ON and OFF switches for the current date
        on_count = sum((fan_state == 1) & (prev_fan_state == 0))
        off_count = sum((fan_state == 0) & (prev_fan_state == 1))
        
        # Update counts in the dictionaries
        fan_on_count[fan_name][date] = on_count
        fan_off_count[fan_name][date] = off_count
        
        # Display fan status for the current date
        total_count = on_count + off_count
        print(f"    {fan_name}: ON: {on_count}, OFF: {off_count}, Total: {total_count}")

    print()
# Out:
# Date: 2023-04-08
#     Fan_1: ON: 0, OFF: 0, Total: 0
#     Fan_2: ON: 0, OFF: 0, Total: 0
#     Fan_3: ON: 0, OFF: 0, Total: 0
#     Fan_4: ON: 0, OFF: 0, Total: 0
#
# Date: 2023-05-06
#     Fan_1: ON: 1, OFF: 0, Total: 1
#     Fan_2: ON: 1, OFF: 0, Total: 1
#     Fan_3: ON: 1, OFF: 0, Total: 1
#     Fan_4: ON: 1, OFF: 0, Total: 1
#
# Date: 2023-04-05
#     Fan_1: ON: 2, OFF: 2, Total: 4
#     Fan_2: ON: 2, OFF: 2, Total: 4
#     Fan_3: ON: 2, OFF: 2, Total: 4
#     Fan_4: ON: 2, OFF: 2, Total: 4
#
# Date: 2023-05-13
#     Fan_1: ON: 2, OFF: 1, Total: 3
#     Fan_2: ON: 2, OFF: 1, Total: 3
#     Fan_3: ON: 2, OFF: 1, Total: 3
#     Fan_4: ON: 2, OFF: 1, Total: 3
#
# Date: 2023-05-12
#     Fan_1: ON: 4, OFF: 3, Total: 7
#     Fan_2: ON: 4, OFF: 3, Total: 7
#     Fan_3: ON: 4, OFF: 3, Total: 7
#     Fan_4: ON: 4, OFF: 3, Total: 7
#
# Date: 2023-05-31
#     Fan_1: ON: 1, OFF: 0, Total: 1
#     Fan_2: ON: 1, OFF: 0, Total: 1
#     Fan_3: ON: 1, OFF: 0, Total: 1
# ...

# %%
# Initialize dictionaries to track count of ON and OFF switches for each fan on each date
fan_on_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}
fan_off_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}

# Get unique dates from the dataset
unique_dates = sorted(set(cold4['P_Date'].dt.date))

# Iterate through each unique date
for date in unique_dates:
    # Iterate through each fan
    for fan_num in range(1, 5):
        fan_name = f'Fan_{fan_num}'
        fan_state = cold4.loc[cold4['P_Date'].dt.date == date, fan_name].values
        
        # Get previous state of the fan
        prev_fan_state = cold4.loc[cold4['P_Date'].dt.date == date, fan_name].shift().values
        prev_fan_state[0] = 0  # For the first row, set previous state to 0
        
        # Count ON and OFF switches for the current date
        on_count = sum((fan_state == 1) & (prev_fan_state == 0))
        off_count = sum((fan_state == 0) & (prev_fan_state == 1))
        
        # Update counts in the dictionaries
        fan_on_count[fan_name][date] = on_count
        fan_off_count[fan_name][date] = off_count

# Plotting the grouped bar plot
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
axes = axes.ravel()

bar_width = 0.35
index = range(len(unique_dates))

for i, fan_name in enumerate(fan_on_count.keys()):
    dates = list(unique_dates)
    on_counts = [fan_on_count[fan_name][date] for date in dates]
    off_counts = [fan_off_count[fan_name][date] for date in dates]

    axes[i].bar(index, on_counts, bar_width, label='ON', color='grey', align='center')
    axes[i].bar(index, off_counts, bar_width, label='OFF', color='black', align='center', bottom=on_counts)
    
    axes[i].set_xlabel('Date')
    axes[i].set_ylabel('Count')
    axes[i].set_title(fan_name)
    axes[i].legend()

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Initialize dictionaries to track count of ON and OFF switches for each fan on each date
fan_on_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}
fan_off_count = {'Fan_1': {}, 'Fan_2': {}, 'Fan_3': {}, 'Fan_4': {}}

# Get unique dates from the dataset
unique_dates = sorted(set(cold4['P_Date'].dt.date))

# Iterate through each unique date
for date in unique_dates:
    # Iterate through each fan
    for fan_num in range(1, 5):
        fan_name = f'Fan_{fan_num}'
        fan_state = cold4.loc[cold4['P_Date'].dt.date == date, fan_name].values
        
        # Get previous state of the fan
        prev_fan_state = cold4.loc[cold4['P_Date'].dt.date == date, fan_name].shift().values
        prev_fan_state[0] = 0  # For the first row, set previous state to 0
        
        # Count ON and OFF switches for the current date
        on_count = sum((fan_state == 1) & (prev_fan_state == 0))
        off_count = sum((fan_state == 0) & (prev_fan_state == 1))
        
        # Update counts in the dictionaries
        fan_on_count[fan_name][date] = on_count
        fan_off_count[fan_name][date] = off_count

# Plotting the graph
fig, axes = plt.subplots(2, 2, figsize=(25, 8))
axes = axes.ravel()

for i, fan_name in enumerate(fan_on_count.keys()):
    dates = list(unique_dates)
    on_counts = [fan_on_count[fan_name][date] for date in dates]
    off_counts = [fan_off_count[fan_name][date] for date in dates]
    # total_counts = [on + off for on, off in zip(on_counts, off_counts)]

    axes[i].plot(dates, on_counts, label='ON', color= 'grey')
    axes[i].plot(dates, off_counts, label='OFF', color= 'black')
    # axes[i].plot(dates, total_counts, label='Total')
    axes[i].set_title(fan_name)
    axes[i].legend()

# Set common labels
fig.text(0.5, 0.04, 'Date', ha='center', va='center')
fig.text(0.06, 0.5, 'Count', ha='center', va='center', rotation='vertical')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **<mark>Conclusion</mark>**

# %% [markdown]
# - **Here the data is distinguished room-wise; Room 1, Room 2, Room 3, Room 4**
# - **Did the corelation matrix to find the elements affecting solenoid valve (SV)**
# - **Found out the total no. of switches made by SV**
# - **Found out the total time the SV was ON and OFF in a particular day**
# - **As heater is directly proportional to SV; found out the heater switch count in a particular day and total time of the same**
# - **As there are 4 fans in the system, analysed the behaviour of the fans with SV**
# - **Compared the behavioural difference of SV and Heater**
